# %% [markdown]
# # <img style="float: left; padding-right: 20px; width: 200px" src="attachment:logo.jpg">  IMT 2200 - Introducción a Ciencia de Datos
# **Pontificia Universidad Católica de Chile**<br>
# **Instituto de Ingeniería Matemática y Computacional**<br>
# **Semestre:** 2024-2<br>
# **Profesor:** Rodrigo A. Carrasco <br>

# %% [markdown]
# # <h1><center>Interrogación 1</center></h1>
#
# ## Instrucciones
#
# * Esta parte de la Interrogación debe ser desarrollada completamente en lenguaje de programación Python en este Notebook de Jupyter.
#
# * El desarrollo del Notebook debe ser claro y ordenado, incluyendo anotaciones (markdown) y comentarios que permitan seguir fácilmente el código y los pasos implementados, y siguiendo buenas prácticas de programación. <br>
# * La entrega de la interrogación se realizará a través de Canvas en la actividad `I1 Desarrollo`.
# * Esta Interrogación debe desarrollarse de manera totalmente *individual*, de acuerdo a lo establecido en la sección de Integridad Académica en el programa del curso.
# * Está **estrictamente prohibido comunicarse con sus compañeros de curso o terceras personas** durante el desarrollo de esta interrogación.
# * Puede consultar los apuntes del curso de todo tipo.
# * Habrá sólo dos instancias para hacer preguntas, una al inicio de la prueba y otra a los 30 minutos de avance.<br>
#
#
# * Ud. dispone de 1 hora para desarrollar esta interrogación.
# * Recuerde **guardar frecuentemente sus avances** para evitar pérdidas de trabajo o problemas de envío.<br>

# %% [markdown]
# ***
# ## Parte 2: Trabajo de Desarrollo (60 min)
#
# Esta parte de la Interrogación es un trabajo práctico con datos. En esta parte, cada pregunta debe ser respondida desarrollando un código por usted que le permita entregar una respuesta. **No se evaluarán respuestas sin código**.

# %% [markdown]
# ## 1. Análisis de Datos de la Filarmónica de NY
#
# Siga los siguientes pasos y luego conteste las preguntas usando los datos disponibles en el repositorio de la Filarmónica de Nueva York.

# %% [markdown]
# ### (*2 pts*) 1.1 Extraer datos de la red
#
# Como vimos en clases, la Filarmónica de NY tiene un repositorio en GitHub donde está la información de todos sus conciertos. Imagine que alguien le entrega la dirección URL donde está el archivo JSON con todos los conciertos y lo almacena en la variable `data_url`

# %% [markdown]
# En la siguiente celda escriba un código que baje a su computador el archivo que se encuentra disponible en el URL almacenado en la variable `data_url`, y lo almacene en su computador bajo el nombre `conciertos.json`. Sólo escriba el código y no lo corra, pues no tiene el URL correspondiente.

# %%
respuesta = requests.get(data_url, stream=False)
open('conciertos.json', 'wb').write(respuesta.content)

# %% [markdown]
# ### 1.2 Lectura y revisión de datos
#
# #### (*10 pt*) 1.2.1 Lectura del archivo local y construcción del DataFrame
#
# En la siguientes celdas (puede agregar celdas si lo necesita) escriba un código que lea el archivo `filarmonica.json` que debió bajar a su computador antes de la prueba y lo deje en un DataFrame de pandas.
#
# Para ello primero cargue el archivo `json`, explore los índices que tiene, y seleccione el adecuado para tener la información de cada programa intepretado por la filarmónica.
#
# Luego, usando los métodos de aplanamiento (`json_normalize`) arme un único DataFrame, llamado `nyphil_df` que tenga las siguientes columnas:
#
# `[ID, composerName, workTitle, conductorName, movement, interval, programID, season, eventType, Location, Venue, Date, Time]`

# %%
import pandas as pd
import json

# leemos los datos
datos_raw = json.load(open('data_2024\\filarmonica.json','r', encoding='UTF-8'))

# %%
print(datos_raw.keys())
# Out:
# {'programs': [{'id': '00646b9f-fec7-4ffb-9fb1-faae410bd9dc-0.1',
#    'programID': '3853',
#    'orchestra': 'New York Philharmonic',
#    'season': '1842-43',
#    'concerts': [{'eventType': 'Subscription Season',
#      'Location': 'Manhattan, NY',
#      'Venue': 'Apollo Rooms',
#      'Date': '1842-12-07T05:00:00Z',
#      'Time': '8:00PM'}],
#    'works': [{'ID': '52446*',
#      'composerName': 'Beethoven,  Ludwig  van',
#      'workTitle': 'SYMPHONY NO. 5 IN C MINOR, OP.67',
#      'conductorName': 'Hill, Ureli Corelli',
#      'soloists': []},
#     {'ID': '8834*4',
#      'composerName': 'Weber,  Carl  Maria Von',
#      'workTitle': 'OBERON',
#      'movement': '"Ozean, du Ungeheuer" (Ocean, thou mighty monster), Reiza (Scene and Aria), Act II',
#      'conductorName': 'Timm, Henry C.',
#      'soloists': [{'soloistName': 'Otto, Antoinette',
#        'soloistInstrument': 'Soprano',
#        'soloistRoles': 'S'}]},
#     {'ID': '3642*',
#      'composerName': 'Hummel,  Johann',
#      'workTitle': 'QUINTET, PIANO, D MINOR, OP. 74',
#      'soloists': [{'soloistName': 'Scharfenberg, William',
#        'soloistInstrument': 'Piano',
#        'soloistRoles': 'A'},
#       {'soloistName': 'Hill, Ureli Corelli',
#        'soloistInstrument': 'Violin',
#        'soloistRoles': 'A'},
#       {'soloistName': 'Derwort, G. H.',
#        'soloistInstrument': 'Viola',
#        'soloistRoles': 'A'},
#       {'soloistName': 'Boucher, Alfred',
#        'soloistInstrument': 'Cello',
#        'soloistRoles': 'A'},
#       {'soloistName': 'Rosier, F. W.',
#        'soloistInstrument': 'Double Bass',
#        'soloistRoles': 'A'}]},
#     {'ID': '0*', 'interval': 'Intermission', 'soloists': []},
#     {'ID': '8834*3',
#      'composerName': 'Weber,  Carl  Maria Von',
#      'workTitle': 'OBERON',
#      'movement': 'Overture',
#      'conductorName': 'Etienne, Denis G.',
#      'soloists': []},
#     {'ID': '8835*1',
#      'composerName': 'Rossini,  Gioachino',
#      'workTitle': 'ARMIDA',
#      'movement': 'Duet',
#      'conductorName': 'Timm, Henry C.',
#      'soloists': [{'soloistName': 'Otto, Antoinette',
#        'soloistInstrument': 'Soprano',
#        'soloistRoles': 'S'},
#       {'soloistName': 'Horn, Charles Edward',
#        'soloistInstrument': 'Tenor',
#        'soloistRoles': 'S'}]},
#     {'ID': '8837*6',
#      'composerName': 'Beethoven,  Ludwig  van',
#      'workTitle': 'FIDELIO, OP. 72',
#      'movement': '"In Des Lebens Fruhlingstagen...O spur ich nicht linde," Florestan (aria)',
#      'conductorName': 'Timm, Henry C.',
#      'soloists': [{'soloistName': 'Horn, Charles Edward',
#        'soloistInstrument': 'Tenor',
#        'soloistRoles': 'S'}]},
#     {'ID': '8336*4',
#      'composerName': 'Mozart,  Wolfgang  Amadeus',
#      'workTitle': 'ABDUCTION FROM THE SERAGLIO,THE, K.384',
#      'movement': '"Ach Ich liebte," Konstanze (aria)',
#      'conductorName': 'Timm, Henry C.',
#      'soloists': [{'soloistName': 'Otto, Antoinette',
#        'soloistInstrument': 'Soprano',
#        'soloistRoles': 'S'}]},
#     {'ID': '5543*',
#      'composerName': 'Kalliwoda,  Johann  W.',
#      'workTitle': 'OVERTURE NO. 1, D MINOR, OP. 38',
#      'conductorName': 'Timm, Henry C.',
#      'soloists': []}]},
#   {'id': '1118e84e-eb59-46cc-9119-d903375e65e6-0.1',
#    'programID': '5178',
#    'orchestra': 'New York Philharmonic',
#    'season': '1842-43',
#    'concerts': [{'eventType': 'Subscription Season',
#      'Location': 'Manhattan, NY',
#      'Venue': 'Apollo Rooms',
#      'Date': '1843-02-18T05:00:00Z',
#      'Time': '8:00PM'}],
#    'works': [{'ID': '52437*',
#      'composerName': 'Beethoven,  Ludwig  van',
#      'workTitle': 'SYMPHONY NO. 3 IN E FLAT MAJOR, OP. 55 (EROICA)',
#      'conductorName': 'Hill, Ureli Corelli',
#      'soloists': []},
#     {'ID': '8838*2',
#      'composerName': 'Bellini,  Vincenzo',
#      'workTitle': 'I PURITANI',
#      'movement': 'Elvira (aria): "Qui la voce...Vien, diletto"',
#      'conductorName': 'Hill, Ureli Corelli',
#      'soloists': [{'soloistName': 'Otto, Antoinette',
#        'soloistInstrument': 'Soprano',
#        'soloistRoles': 'S'}]},
#     {'ID': '3659*',
#      'composerName': 'Romberg,  Bernhard',
#      'workTitle': 'CELEBRATED ELEGIE',
#      'conductorName': 'Hill, Ureli Corelli',
#      'soloists': [{'soloistName': 'Boucher, Alfred',
#        'soloistInstrument': 'Cello',
#        'soloistRoles': 'S'}]},
#     {'ID': '0*', 'interval': 'Intermission', 'soloists': []},
#     {'ID': '8839*2',
#      'composerName': 'Rossini,  Gioachino',
#      'workTitle': 'WILLIAM TELL',
#      'movement': 'Overture',
#      'conductorName': 'Alpers, William',
#      'soloists': []},
#     {'ID': '53076*2',
#      'composerName': 'Rossini,  Gioachino',
#      'workTitle': 'STABAT MATER',
#      'movement': 'Inflammatus et Accensus (Aria with Chorus)',
#      'conductorName': 'Alpers, William',
#      'soloists': [{'soloistName': 'Otto, Antoinette',
#        'soloistInstrument': 'Soprano',
#        'soloistRoles': 'S'}]},
#     {'ID': '51568*2',
#      'composerName': 'Hummel,  Johann',
#      'workTitle': 'CONCERTO, PIANO, A-FLAT MAJOR, OP. 113',
#      'movement': 'Romanza: Larghetto con moto',
#      'conductorName': 'Alpers, William',
#      'soloists': [{'soloistName': 'Timm, Henry C.',
#        'soloistInstrument': 'Piano',
#        'soloistRoles': 'S'}]},
#     {'ID': '51568*3',
#      'composerName': 'Hummel,  Johann',
#      'workTitle': 'CONCERTO, PIANO, A-FLAT MAJOR, OP. 113',
#      'movement': 'Rondo alla spagniola: Allegro moderato',
#      'conductorName': 'Alpers, William',
#      'soloists': [{'soloistName': 'Timm, Henry C.',
#        'soloistInstrument': 'Piano',
#        'soloistRoles': 'S'}]},
#     {'ID': '6709*16',
#      'composerName': 'Weber,  Carl  Maria Von',
#      'workTitle': 'FREISCHUTZ, DER',
#      'movement': 'Overture',
#      'conductorName': 'Alpers, William',
#      'soloists': []}]},
#   {'id': '08536612-27c3-437e-9b44-def21034b06c-0.1',
#    'programID': '10785',
#    'orchestra': 'Musicians from the New York Philharmonic',
#    'season': '1842-43',
#    'concerts': [{'eventType': 'Special',
#      'Location': 'Manhattan, NY',
#      'Venue': 'Apollo Rooms',
#      'Date': '1843-04-07T05:00:00Z',
#      'Time': '8:00PM'}],
#    'works': [{'ID': '52364*1',
#      'composerName': 'Beethoven,  Ludwig  van',
#      'workTitle': 'EGMONT, OP.84',
#      'movement': 'Overture',
#      'conductorName': 'Hill, Ureli Corelli',
#      'soloists': []},
#     {'ID': '8834*4',
#      'composerName': 'Weber,  Carl  Maria Von',
#      'workTitle': 'OBERON',
#      'movement': '"Ozean, du Ungeheuer" (Ocean, thou mighty monster), Reiza (Scene and Aria), Act II',
#      'conductorName': 'Not conducted',
#      'soloists': [{'soloistName': 'Otto, Antoinette',
#        'soloistInstrument': 'Soprano',
#        'soloistRoles': 'S'},
#       {'soloistName': 'Timm, Henry C.',
#        'soloistInstrument': 'Piano',
#        'soloistRoles': 'A'}]},
#     {'ID': '4567*',
#      'composerName': 'Hummel,  Johann',
#      'workTitle': 'CONCERTO, PIANO, A MINOR, OP. 85',
#      'conductorName': 'Hill, Ureli Corelli',
#      'soloists': [{'soloistName': 'Scharfenberg, William',
#        'soloistInstrument': 'Piano',
#        'soloistRoles': 'S'}]},
#     {'ID': '5150*',
#      'composerName': 'Pacini,  Giovanni',
#      'workTitle': 'O HAPPY HAPPY HOUR',
#      'conductorName': 'Not conducted',
#      'soloists': [{'soloistName': 'Otto, Antoinette',
#        'soloistInstrument': 'Soprano',
#        'soloistRoles': 'S'},
#       {'soloistName': 'Timm, Henry C.',
#        'soloistInstrument': 'Piano',
#        'soloistRoles': 'A'}]},
#     {'ID': '5161*',
#      'composerName': 'Romberg,  Bernhard',
#      'workTitle': 'FANTASIA ON SWEEDISH AIRS',
#      'conductorName': 'Not conducted',
#      'soloists': [{'soloistName': 'Boucher, Alfred',
#        'soloistInstrument': 'Cello',
#        'soloistRoles': 'S'}]},
#     {'ID': '5162*2',
#      'composerName': 'Onslow,  George',
#      'workTitle': 'SEXTET IN E FLAT MAJOR, OP. 30',
#      'movement': 'Andante con variazioni',
#      'conductorName': 'Not conducted',
#      'soloists': [{'soloistName': 'Scharfenberg, William',
#        'soloistInstrument': 'Piano',
#        'soloistRoles': 'S'},
#       {'soloistName': 'Lehman',
#        'soloistInstrument': 'Flute',
#        'soloistRoles': 'A'},
#       {'soloistName': 'Groneveldt, Theodore W.',
#        'soloistInstrument': 'Clarinet',
#        'soloistRoles': 'A'},
#       {'soloistName': 'Hegelund, H. W.',
#        'soloistInstrument': 'Bassoon',
#        'soloistRoles': 'A'},
#       {'soloistName': 'Woehning, F. C.',
#        'soloistInstrument': 'French Horn',
#        'soloistRoles': 'A'},
#       {'soloistName': 'Rosier, F. W.',
#        'soloistInstrument': 'Double Bass',
#        'soloistRoles': 'A'}]},
#     {'ID': '5162*3',
#      'composerName': 'Onslow,  George',
#      'workTitle': 'SEXTET IN E FLAT MAJOR, OP. 30',
#      'movement': 'Minuetto',
#      'conductorName': 'Not conducted',
#      'soloists': [{'soloistName': '',
#        'soloistInstrument': '',
#        'soloistRoles': ''},
#       {'soloistName': 'Scharfenberg, William',
#        'soloistInstrument': 'Piano',
#        'soloistRoles': 'S'},
#       {'soloistName': 'Lehman',
#        'soloistInstrument': 'Flute',
#        'soloistRoles': 'A'},
#       {'soloistName': 'Groneveldt, Theodore W.',
#        'soloistInstrument': 'Clarinet',
#        'soloistRoles': 'A'},
#       {'soloistName': 'Hegelund, H. W.',
#        'soloistInstrument': 'Bassoon',
#        'soloistRoles': 'A'},
#       {'soloistName': 'Woehning, F. C.',
#        'soloistInstrument': 'French Horn',
#        'soloistRoles': 'A'},
#       {'soloistName': 'Rosier, F. W.',
#        'soloistInstrument': 'Double Bass',
#        'soloistRoles': 'A'}]},
#     {'ID': '8839*2',
#      'composerName': 'Rossini,  Gioachino',
#      'workTitle': 'WILLIAM TELL',
#      'movement': 'Overture',
#      'conductorName': 'Alpers, William',
#      'soloists': []},
#     {'ID': '5166*',
#      'composerName': 'Thalberg,  Sigismond',
#      'workTitle': 'FANTASIA AND VARIATIONS ON THEMES FROM NORMA, OP. 12 (FOUR HANDS)',
#      'conductorName': 'Not conducted',
#      'soloists': [{'soloistName': '',
#        'soloistInstrument': '',
#        'soloistRoles': ''},
#       {'soloistName': 'Rakeman, Frederick',
#        'soloistInstrument': 'Piano',
#        'soloistRoles': 'S'},
#       {'soloistName': 'Scharfenberg, William',
#        'soloistInstrument': 'Piano',
#        'soloistRoles': 'S'}]},
#     {'ID': '8955*13',
#      'composerName': 'Mozart,  Wolfgang  Amadeus',
#      'workTitle': 'MAGIC FLUTE, THE, K.620',
#      'movement': 'Aria (unspecified)',
#      'conductorName': 'Not conducted',
#      'soloists': [{'soloistName': '',
#        'soloistInstrument': '',
#        'soloistRoles': ''},
#       {'soloistName': 'Otto, Antoinette',
#        'soloistInstrument': 'Soprano',
#        'soloistRoles': 'S'},
#       {'soloistName': 'Timm, Henry C.',
#        'soloistInstrument': 'Piano',
#        'soloistRoles': 'A'}]},
#     {'ID': '5172*',
#      'composerName': 'Herz,  Henri',
#      'workTitle': 'INTRODUCTION AND VARIATIONS ON THE ROMANCE OF JOSEPH, OP. 20',
#      'conductorName': 'Alpers, William',
#      'soloists': [{'soloistName': '',
#        'soloistInstrument': '',
#        'soloistRoles': ''},
#       {'soloistName': 'Scharfenberg, William',
#        'soloistInstrument': 'Piano',
#        'soloistRoles': 'S'}]},
#     {'ID': '5174*',
#      'composerName': 'Lindpaintner,  Peter  Von',
#      'workTitle': 'QUINTET FOR WINDS AND ORCHESTRA',
#      'conductorName': 'Not conducted',
#      'soloists': [{'soloistName': 'Lehman',
#        'soloistInstrument': 'Flute',
#        'soloistRoles': 'A'},
#       {'soloistName': 'Wiese, Frederick',
#        'soloistInstrument': 'Oboe',
#        'soloistRoles': 'A'},
#       {'soloistName': 'Groneveldt, Theodore W.',
#        'soloistInstrument': 'Clarinet',
#        'soloistRoles': 'A'},
#       {'soloistName': 'Hegelund, H. W.',
#        'soloistInstrument': 'Bassoon',
#        'soloistRoles': 'A'},
#       {'soloistName': 'Woehning, F. C.',
#        'soloistInstrument': 'French Horn',
#        'soloistRoles': 'A'}]}]},
#   {'id': '81a3b8de-1737-4c9e-9318-b839f7c7c4c0-0.1',
#    'programID': '5887',
#    'orchestra': 'New York Philharmonic',
#    'season': '1842-43',
#    'concerts': [{'eventType': 'Subscription Season',
#      'Location': 'Manhattan, NY',
#      'Venue': 'Apollo Rooms',
#      'Date': '1843-04-22T05:00:00Z',
#      'Time': '8:00PM'}],
#    'works': [{'ID': '52434*',
#      'composerName': 'Beethoven,  Ludwig  van',
#      'workTitle': 'SYMPHONY NO. 2 IN D MAJOR, OP.36',
#      'conductorName': 'Boucher, Alfred',
#      'soloists': []},
#     {'ID': '3666*',
#      'composerName': 'Haydn,  Franz  Joseph',
#      'workTitle': 'SYMPATHY, HXXVIA:33 (VOICE AND ORCH) (ARR. Loder)',
#      'conductorName': 'Loder, George',
#      'soloists': [{'soloistName': 'Loder, Edward',
#        'soloistInstrument': 'Vocalist',
#        'soloistRoles': 'S'}]},
#     {'ID': '5801*1',
#      'composerName': 'Mendelssohn,  Felix',
#      'workTitle': "MIDSUMMER NIGHT'S DREAM, OP. 61",
#      'movement': 'Overture',
#      'conductorName': 'Loder, George',
#      'soloists': []},
#     {'ID': '0*', 'interval': 'Intermission', 'soloists': []},
#     {'ID': '52425*',
#      'composerName': 'Beethoven,  Ludwig  van',
#      'workTitle': 'SEPTET, E-FLAT MAJOR, OP.20',
#      'soloists': [{'soloistName': 'Groneveldt, Theodore W.',
#        'soloistInstrument': 'Clarinet',
#        'soloistRoles': 'A'},
#       {'soloistName': 'Reiff, Anton, Sr.',
#        'soloistInstrument': 'Bassoon',
#        'soloistRoles': 'A'},
#       {'soloistName': 'Trojsi, Gaetano',
#        'soloistInstrument': 'French Horn',
#        'soloistRoles': 'A'},
#       {'soloistName': 'Hill, Ureli Corelli',
#        'soloistInstrument': 'Violin',
#        'soloistRoles': 'A'},
#       {'soloistName': 'Wiegers, Louis',
#        'soloistInstrument': 'Viola',
#        'soloistRoles': 'A'},
#       {'soloistName': 'Boucher, Alfred',
#        'soloistInstrument': 'Cello',
#        'soloistRoles': 'A'},
#       {'soloistName': 'Rosier, F. W.',
#        'soloistInstrument': 'Double Bass',
#        'soloistRoles': 'A'}]},
#     {'ID': '3674*',
#      'composerName': 'Spohr,  Louis',
#      'workTitle': "E MI LASCI COSÌ? ... TU M'ABBANDONI, INGRATO, OP. 71",
#      'conductorName': 'Loder, George',
#      'soloists': [{'soloistName': 'Loder, Edward',
#        'soloistInstrument': 'Vocalist',
#        'soloistRoles': 'S'}]},
#     {'ID': '50729*',
#      'composerName': 'Weber,  Carl  Maria Von',
#      'workTitle': 'JUBEL OVERTURE, OP. 59',
#      'conductorName': 'Loder, George',
#      'soloists': []}]},
#   {'id': '09581bb7-8855-4965-b302-fc54cc669041-0.1',
#    'programID': '305',
#    'orchestra': 'New York Philharmonic',
#    'season': '1843-44',
#    'concerts': [{'eventType': 'Subscription Season',
#      'Location': 'Manhattan, NY',
#      'Venue': 'Apollo Rooms',
#      'Date': '1843-11-18T05:00:00Z',
#      'Time': 'None'}],
#    'works': [{'ID': '52453*',
#      'composerName': 'Beethoven,  Ludwig  van',
#      'workTitle': 'SYMPHONY NO. 7 IN A MAJOR, OP.92',
#      'conductorName': 'Hill, Ureli Corelli',
#      'soloists': []},
#     {'ID': '3677*1',
#      'composerName': 'Nini,  Alessandro',
#      'workTitle': 'IDA DELLA TORRE',
#      'movement': 'Cavatina: "Quando quell \'oum quell \'unico"',
#      'conductorName': 'Hill, Ureli Corelli',
#      'soloists': [{'soloistName': 'Castellan, Jeanne Anais',
#        'soloistInstrument': 'Soprano',
#        'soloistRoles': 'S'}]},
#     {'ID': '0*', 'interval': 'Intermission', 'soloists': []},
#     {'ID': '8955*1',
#      'composerName': 'Mozart,  Wolfgang  Amadeus',
#      'workTitle': 'MAGIC FLUTE, THE, K.620',
#      'movement': 'Overture',
#      'conductorName': 'Hill, Ureli Corelli',
#      'soloists': []},
#     {'ID': '5190*3',
#      'composerName': 'Donizetti,  Gaetano',
#      'workTitle': 'LUCIA DI LAMMERMOOR',
#      'movement': '"Regnava nel silenzio," Lucia (aria), Act I, scene ii',
#      'conductorName': 'Hill, Ureli Corelli',
#      'soloists': [{'soloistName': 'Castellan, Jeanne Anais',
#        'soloistInstrument': 'Soprano',
#        'soloistRoles': 'S'}]},
#     {'ID': '50729*',
#      'composerName': 'Weber,  Carl  Maria Von',
#      'workTitle': 'JUBEL OVERTURE, OP. 59',
#      'conductorName': 'Hill, Ureli Corelli',
#      'soloists': []}]},
#   {'id': '0848266c-8eee-48ae-8299-dcdb1120b0a2-0.1',
#    'programID': '3368',
#    'orchestra': 'New York Philharmonic',
#    'season': '1843-44',
#    'concerts': [{'eventType': 'Subscription Season',
#      'Location': 'Manhattan, NY',
#      'Venue': 'Apollo Rooms',
#      'Date': '1844-01-13T05:00:00Z',
#      'Time': '8:00PM'}],
#    'works': [{'ID': '51668*',
#      'composerName': 'Mozart,  Wolfgang  Amadeus',
#      'workTitle': 'SYMPHONY NO. 41, C MAJOR, K.551, "JUPITER"',
#      'conductorName': 'Etienne, Denis G.',
#      'soloists': []},
#     {'ID': '5190*2',
#      'composerName': 'Donizetti,  Gaetano',
#      'workTitle': 'LUCIA DI LAMMERMOOR',
#      'movement': '"Il dolce suono" (Mad Scene), Lucia (aria), Act III, scene i',
#      'conductorName': 'Etienne, Denis G.',
#      'soloists': [{'soloistName': 'Castellan, Jeanne Anais',
#        'soloistInstrument': 'Soprano',
#        'soloistRoles': 'S'}]},
#     {'ID': '3999*1',
#      'composerName': 'Hummel,  Johann',
#      'workTitle': 'SEPTET, D MINOR, OP. 74',
#      'movement': 'Allegro con spirito',
#      'soloists': [{'soloistName': 'Scharfenberg, William',
#        'soloistInstrument': 'Piano',
#        'soloistRoles': 'A'},
#       {'soloistName': 'Kyle, John A.',
#        'soloistInstrument': 'Flute',
#        'soloistRoles': 'A'},
#       {'soloistName': 'Woehning, F. C.',
#        'soloistInstrument': 'French Horn',
#        'soloistRoles': 'A'},
#       {'soloistName': 'Boucher, Alfred',
#        'soloistInstrument': 'Cello',
#        'soloistRoles': 'A'},
#       {'soloistName': 'Wiese, Frederick',
#        'soloistInstrument': 'Oboe',
#        'soloistRoles': 'A'},
#       {'soloistName': 'Johnson',
#        'soloistInstrument': 'Tenor',
#        'soloistRoles': 'A'},
#       {'soloistName': 'Rosier, F. W.',
#        'soloistInstrument': 'Double Bass',
#        'soloistRoles': 'A'}]},
#     {'ID': '3999*2',
#      'composerName': 'Hummel,  Johann',
#      'workTitle': 'SEPTET, D MINOR, OP. 74',
#      'movement': 'Menuetto o Scherzo - Allegro',
#      'soloists': [{'soloistName': 'Scharfenberg, William',
#        'soloistInstrument': 'Piano',
#        'soloistRoles': 'A'},
#       {'soloistName': 'Kyle, John A.',
#        'soloistInstrument': 'Flute',
#        'soloistRoles': 'A'},
#       {'soloistName': 'Woehning, F. C.',
#        'soloistInstrument': 'French Horn',
#        'soloistRoles': 'A'},
#       {'soloistName': 'Boucher, Alfred',
#        'soloistInstrument': 'Cello',
#        'soloistRoles': 'A'},
#       {'soloistName': 'Wiese, Frederick',
#        'soloistInstrument': 'Oboe',
#        'soloistRoles': 'A'},
#       {'soloistName': 'Johnson',
#        'soloistInstrument': 'Tenor',
#        'soloistRoles': 'A'},
#       {'soloistName': 'Rosier, F. W.',
#        'soloistInstrument': 'Double Bass',
#        'soloistRoles': 'A'}]},
#     {'ID': '0*', 'interval': 'Intermission', 'soloists': []},
#     {'ID': '3696*',
#      'composerName': 'Kalliwoda,  Johann  W.',
#      'workTitle': 'OVERTURE, F MAJOR',
#      'conductorName': 'Etienne, Denis G.',
#      'soloists': []},
#     {'ID': '3700*1',
#      'composerName': 'Bellini,  Vincenzo',
#      'workTitle': 'LA SONNAMBULA',
#      'movement': '"Ah! non credea mirarti... Ah non giunge," Amina (aria)',
#      'conductorName': 'Etienne, Denis G.',
#      'soloists': [{'soloistName': 'Castellan, Jeanne Anais',
#        'soloistInstrument': 'Soprano',
#        'soloistRoles': 'S'}]},
#     {'ID': '3704*1',
#      'composerName': 'Reicha,  Antoine(-Joseph)',
#      'workTitle': 'QUINTET',
#      'movement': 'Adagio',
#      'soloists': [{'soloistName': 'Kyle, John A.',
#        'soloistInstrument': 'Flute',
#        'soloistRoles': 'A'},
#       {'soloistName': 'Wiese, Frederick',
#        'soloistInstrument': 'Oboe',
#        'soloistRoles': 'A'},
#       {'soloistName': 'Groneveldt, Theodore W.',
#        'soloistInstrument': 'Clarinet',
#        'soloistRoles': 'A'},
#       {'soloistName': 'Woehning, F. C.',
#        'soloistInstrument': 'French Horn',
#        'soloistRoles': 'A'},
#       {'soloistName': 'Reiff, Anton, Sr.',
#        'soloistInstrument': 'Bassoon',
#        'soloistRoles': 'A'}]},
#     {'ID': '3704*2',
#      'composerName': 'Reicha,  Antoine(-Joseph)',
#      'workTitle': 'QUINTET',
#      'movement': 'Finale',
#      'soloists': [{'soloistName': 'Kyle, John A.',
#        'soloistInstrument': 'Flute',
#        'soloistRoles': 'A'},
#       {'soloistName': 'Wiese, Frederick',
#        'soloistInstrument': 'Oboe',
#        'soloistRoles': 'A'},
#       {'soloistName': 'Groneveldt, Theodore W.',
#        'soloistInstrument': 'Clarinet',
#        'soloistRoles': 'A'},
#       {'soloistName': 'Woehning, F. C.',
#        'soloistInstrument': 'French Horn',
#        'soloistRoles': 'A'},
#       {'soloistName': 'Reiff, Anton, Sr.',
#        'soloistInstrument': 'Bassoon',
#        'soloistRoles': 'A'}]},
#     {'ID': '50093*1',
#      'composerName': 'Herold,  Louis  Joseph Ferdinand [Hérold]',
#      'workTitle': 'ZAMPA',
#      'movement': 'Overture',
#      'conductorName': 'Etienne, Denis G.',
#      'soloists': []}]},
#   {'id': '8025e763-9c12-4157-93b6-a20b32fd1f0e-0.1',
#    'programID': '4226',
#    'orchestra': 'New York Philharmonic',
#    'season': '1843-44',
#    'concerts': [{'eventType': 'Subscription Season',
#      'Location': 'Manhattan, NY',
#      'Venue': 'Apollo Rooms',
#      'Date': '1844-03-16T05:00:00Z',
#      'Time': 'None'}],
#    'works': [{'ID': '3707*',
#      'composerName': 'Spohr,  Louis',
#      'workTitle': 'SYMPHONY NO. 2, D MINOR, OP. 49',
#      'conductorName': 'Loder, George',
#      'soloists': []},
#     {'ID': '3712*',
#      'composerName': 'Bochsa,  Robert  N. C.',
#      'workTitle': 'DIALOGO BRILLIANTE',
#      'soloists': [{'soloistName': 'Kyle, John A.',
#        'soloistInstrument': 'Flute',
#        'soloistRoles': 'A'},
#       {'soloistName': 'Groneveldt, Theodore W.',
#        'soloistInstrument': 'Clarinet',
#        'soloistRoles': 'A'}]},
#     {'ID': '0*', 'interval': 'Intermission', 'soloists': []},
#     {'ID': '51710*1',
#      'composerName': 'Rossini,  Gioachino',
#      'workTitle': 'SEMIRAMIDE',
#      'movement': 'Overture',
#      'conductorName': 'Loder, George',
#      'soloists': []},
#     {'ID': '7773*1',
#      'composerName': 'Hummel,  Johann',
#      'workTitle': 'CONCERTO, PIANO, B MINOR',
#      'movement': 'Allegro moderato',
#      'conductorName': 'Loder, George',
#      'soloists': [{'soloistName': 'Timm, Henry C.',
#        'soloistInstrument': 'Piano',
#        'soloistRoles': 'S'}]},
#     {'ID': '9187*1',
#      'composerName': 'Weber,  Carl  Maria Von',
#      'workTitle': 'EURYANTHE, OP. 81, J. 291',
#      'movement': 'Overture',
#      'conductorName': 'Loder, George',
#      'soloists': []}]},
#   {'id': '19d44866-ee7b-48d7-9a27-8f7c8070292c-0.1',
#    'programID': '5087',
#    'orchestra': 'New York Philharmonic',
#    'season': '1843-44',
#    'concerts': [{'eventType': 'Subscription Season',
#      'Location': 'Manhattan, NY',
#      'Venue': 'Apollo Rooms',
#      'Date': '1844-05-18T05:00:00Z',
#      'Time': 'None'}],
#    'works': [{'ID': '52446*',
#      'composerName': 'Beethoven,  Ludwig  van',
#      'workTitle': 'SYMPHONY NO. 5 IN C MINOR, OP.67',
#      'conductorName': 'Alpers, William',
#      'soloists': []},
#     {'ID': '3719*',
#      'composerName': 'Vieuxtemps,  Henri',
#      'workTitle': 'FANTASIA POUR LE VIOLON SUR LA QUATRIEME CORDE',
#      'conductorName': 'Alpers, William',
#      'soloists': [{'soloistName': 'Vieuxtemps, Henri',
#        'soloistInstrument': 'Violin',
#        'soloistRoles': 'S'}]},
#     {'ID': '5801*1',
#      'composerName': 'Mendelssohn,  Felix',
#      'workTitle': "MIDSUMMER NIGHT'S DREAM, OP. 61",
#      'movement': 'Overture',
#      'conductorName': 'Alpers, William',
#      'soloists': []},
#     {'ID': '3722*',
#      'composerName': 'Donizetti,  Gaetano',
#      'workTitle': 'ARIA [UNSPECIFIED]',
#      'conductorName': 'Alpers, William',
#      'soloists': [{'soloistName': 'Valtellina',
#        'soloistInstrument': 'Tenor',
#        'soloistRoles': 'S'}]},
#     {'ID': '50743*',
#      'composerName': 'Weber,  Carl  Maria Von',
#      'workTitle': 'RULER OF THE SPIRITS: OVERTURE, OP. 27',
#      'conductorName': 'Alpers, William',
#      'soloists': []}]},
#   {'id': '4f13ab38-9eb4-4148-92e4-6e228ecddb03-0.1',
#    'programID': '6310',
#    'orchestra': 'New York Philharmonic',
#    'season': '1844-45',
#    'concerts': [{'eventType': 'Subscription Season',
#      'Location': 'Manhattan, NY',
#      'Venue': 'Apollo Rooms',
#      'Date': '1844-11-16T05:00:00Z',
#      'Time': '8:00PM'}],
#    'works': [{'ID': '52456*',
#      'composerName': 'Beethoven,  Ludwig  van',
#      'workTitle': 'SYMPHONY NO. 8 IN F MAJOR, OP.93',
#      'conductorName': 'Loder, George',
#      'soloists': []},
#     {'ID': '3208*2',
#      'composerName': 'Donizetti,  Gaetano',
#      'workTitle': "L'ELISIR D'AMORE",
#      'movement': '"Quanto Amore," Adina/Dulcamara (duet)',
#      'conductorName': 'Loder, George',
#      'soloists': [{'soloistName': 'Ricci, Amalia',
#        'soloistInstrument': 'Vocalist',
#        'soloistRoles': 'S'},
#       {'soloistName': 'Sanquirico',
#        'soloistInstrument': 'Vocalist',
#        'soloistRoles': 'S'}]},
#     {'ID': '0*', 'interval': 'Intermission', 'soloists': []},
#     {'ID': '52512*',
#      'composerName': 'Mendelssohn,  Felix',
#      'workTitle': "HEBRIDES (FINGAL'S CAVE) OVERTURE, OP.26",
#      'conductorName': 'Loder, George',
#      'soloists': []},
#     {'ID': '3730*',
#      'composerName': 'Donizetti,  Gaetano',
#      'workTitle': 'CONVENIENSI TEATRALI',
#      'conductorName': 'Loder, George',
#      'soloists': [{'soloistName': 'Sanquirico',
#        'soloistInstrument': 'Vocalist',
#        'soloistRoles': 'S'}]},
#     {'ID': '3734*1',
#      'composerName': 'Donizetti,  Gaetano',
#      'workTitle': 'BELISARIO',
#      'movement': 'Cavatina [unspecified]',
#      'conductorName': 'Loder, George',
#      'soloists': [{'soloistName': 'Ricci, Amalia',
#        'soloistInstrument': 'Vocalist',
#        'soloistRoles': 'S'}]},
#     {'ID': '3737*',
#      'composerName': 'Lindpaintner,  Peter  Von',
#      'workTitle': 'WAR JUBILEE',
#      'conductorName': 'Loder, George',
#      'soloists': []},
#     {'ID': '52512*',
#      'composerName': 'Mendelssohn,  Felix',
#      'workTitle': "HEBRIDES (FINGAL'S CAVE) OVERTURE, OP.26",
#      'conductorName': 'Loder, George',
#      'soloists': []}]},
#   {'id': '7725e2f7-7f77-41de-a1b3-c4418f6c98dd-0.1',
#    'programID': '1979',
#    'orchestra': 'New York Philharmonic',
#    'season': '1844-45',
#    'concerts': [{'eventType': 'Subscription Season',
#      'Location': 'Manhattan, NY',
#      'Venue': 'Apollo Rooms',
#      'Date': '1845-01-11T05:00:00Z',
#      'Time': '8:00PM'}],
#    'works': [{'ID': '51727*',
#      'composerName': 'Haydn,  Franz  Joseph',
#      'workTitle': 'SYMPHONY NO.   3, G MAJOR',
#      'conductorName': 'Hill, Ureli Corelli',
#      'soloists': []},
#     {'ID': '6709*13',
#      'composerName': 'Weber,  Carl  Maria Von',
#      'workTitle': 'FREISCHUTZ, DER',
#      'movement': '"Wie nahte mir der Schlummer...Leise, leise, fromme Weise," Agathe (Scene and Aria), Act II',
#      'conductorName': 'Hill, Ureli Corelli',
#      'soloists': [{'soloistName': 'Loder, Edward',
#        'soloistInstrument': 'Vocalist',
#        'soloistRoles': 'S'}]},
#     {'ID': '50710*',
#      'composerName': 'Weber,  Carl  Maria Von',
#      'workTitle': 'CONCERTINO, CLARINET,  E FLAT MAJOR, OP. 26',
#      'conductorName': 'Hill, Ureli Corelli',
#      'soloists': [{'soloistName': 'Groneveldt, Theodore W.',
#        'soloistInstrument': 'Clarinet',
#        'soloistRoles': 'S'}]},
#     {'ID': '0*', 'interval': 'Intermission', 'soloists': []},
#     {'ID': '3745*1',
#      'composerName': 'Spohr,  Louis',
#      'workTitle': 'JESSONDA',
#      'movement': 'Overture',
#      'conductorName': 'Hill, Ureli Corelli',
#      'soloists': []},
#     {'ID': '8863*4',
#      'composerName': 'Mozart,  Wolfgang  Amadeus',
#      'workTitle': 'CLEMENZA DI TITO, LA, K.621',
#      'movement': '"Deh, per questo istante solo"',
#      'conductorName': 'Hill, Ureli Corelli',
#      'soloists': [{'soloistName': 'Loder, Edward',
#        'soloistInstrument': 'Vocalist',
#        'soloistRoles': 'S'}]},
#     {'ID': '8837*14',
#      'composerName': 'Beethoven,  Ludwig  van',
#      'workTitle': 'FIDELIO, OP. 72',
#      'movement': '"Mir ist so wunderbar," Quartet',
#      'conductorName': 'Hill, Ureli Corelli',
#      'soloists': [{'soloistName': 'Loder, Edward',
#        'soloistInstrument': 'Vocalist',
#        'soloistRoles': 'S'},
#       {'soloistName': 'De Luce',
#        'soloistInstrument': 'Vocalist',
#        'soloistRoles': 'S'},
#       {'soloistName': 'Munson',
#        'soloistInstrument': 'Vocalist',
#        'soloistRoles': 'S'},
#       {'soloistName': 'Massett, J. Schwartz',
#        'soloistInstrument': 'Vocalist',
#        'soloistRoles': 'S'}]},
#     {'ID': '3757*1',
#      'composerName': 'Marschner,  Heinrich  August',
#      'workTitle': 'VAMPYR, LE, OP. 42',
#      'movement': 'Overture',
#      'conductorName': 'Hill, Ureli Corelli',
#      'soloists': []}]},
#   {'id': 'f1de3488-6831-408d-818b-0311c2423866-0.1',
#    'programID': '2821',
#    'orchestra': 'New York Philharmonic',
#    'season': '1844-45',
#    'concerts': [{'eventType': 'Subscription Season',
#      'Location': 'Manhattan, NY',
#      'Venue': 'Apollo Rooms',
#      'Date': '1845-03-01T05:00:00Z',
#      'Time': '8:00PM'}],
#    'works': [{'ID': '52437*',
#      'composerName': 'Beethoven,  Ludwig  van',
#      'workTitle': 'SYMPHONY NO. 3 IN E FLAT MAJOR, OP. 55 (EROICA)',
#      'conductorName': 'Wiegers, Louis',
#      'soloists': []},
#     {'ID': '3761*',
#      'composerName': 'Donizetti,  Gaetano',
#      'workTitle': 'RONDO-FINALE, "CHE D\'ALLA GIOJA"',
#      'conductorName': 'Wiegers, Louis',
#      'soloists': [{'soloistName': 'Arnoult',
#        'soloistInstrument': 'Vocalist',
#        'soloistRoles': 'S'}]},
#     {'ID': '3764*',
#      'composerName': 'Lindpaintner,  Peter  Von',
#      'workTitle': 'SINFONIA CONCERTANTE NO. 2',
#      'soloists': [{'soloistName': 'Kyle, John A.',
#        'soloistInstrument': 'Flute',
#        'soloistRoles': 'A'},
#       {'soloistName': 'Wiese, Frederick',
#        'soloistInstrument': 'Oboe',
#        'soloistRoles': 'A'},
#       {'soloistName': 'Groneveldt, Theodore W.',
#        'soloistInstrument': 'Clarinet',
#        'soloistRoles': 'A'},
#       {'soloistName': 'Reiff, Anton, Sr.',
#        'soloistInstrument': 'Bassoon',
#        'soloistRoles': 'A'},
#       {'soloistName': 'Trojsi, Gaetano',
#        'soloistInstrument': 'French Horn',
#        'soloistRoles': 'A'}]},
#     {'ID': '0*', 'interval': 'Intermission', 'soloists': []},
#     {'ID': '3768*',
#      'composerName': 'Bennett,  William  Sterndale',
#      'workTitle': 'DIE NAJADEN, OP.15',
#      'conductorName': 'Wiegers, Louis',
#      'soloists': []},
#     {'ID': '3867*1',
#      'composerName': 'Meyerbeer,  Giacomo',
#      'workTitle': 'ROBERT LE DIABLE',
#      'movement': '"Grace, Seigneur," Isabelle (aria)',
#      'conductorName': 'Wiegers, Louis',
#      'soloists': [{'soloistName': 'Arnoult',
#        'soloistInstrument': 'Vocalist',
#        'soloistRoles': 'S'}]},
#     {'ID': '3712*',
#      'composerName': 'Bochsa,  Robert  N. C.',
#      'workTitle': 'DIALOGO BRILLIANTE',
#      'soloists': [{'soloistName': 'Kyle, John A.',
#        'soloistInstrument': 'Flute',
#        'soloistRoles': 'S'},
#       {'soloistName': 'Groneveldt, Theodore W.',
#        'soloistInstrument': 'Clarinet',
#        'soloistRoles': 'S'}]},
#     {'ID': '3776*',
#      'composerName': 'Ries,  Ferdinand',
#      'workTitle': 'GROSSE FEST-OVERTURE UND SIEGESMARSCH',
#      'conductorName': 'Wiegers, Louis',
#      'soloists': []}]},
#   {'id': 'cd444e18-1fcd-4d66-8c1a-8b74e5b001a2-0.1',
#    'programID': '3259',
#    'orchestra': 'New York Philharmonic',
#    'season': '1844-45',
#    'concerts': [{'eventType': 'Subscription Season',
#      'Location': 'Manhattan, NY',
#      'Venue': 'Apollo Rooms',
#      'Date': '1845-04-19T05:00:00Z',
#      'Time': '8:00PM'}],
#    'works': [{'ID': '52453*',
#      'composerName': 'Beethoven,  Ludwig  van',
#      'workTitle': 'SYMPHONY NO. 7 IN A MAJOR, OP.92',
#      'conductorName': 'Hill, Ureli Corelli',
#      'soloists': []},
#     {'ID': '0*', 'interval': 'Intermission', 'soloists': []},
#     {'ID': '4945*',
#      'composerName': 'Mendelssohn,  Felix',
#      'workTitle': 'MELUSINE: OVERTURE',
#      'conductorName': 'Hill, Ureli Corelli',
#      'soloists': []},
#     {'ID': '3781*1',
#      'composerName': 'Kreutzer,  Conradin',
#      'workTitle': 'NACHTLAGER IN GRANADA, DAS',
#      'movement': '"Seine fromme Liebes-Gabe," Gabriele (aria)',
#      'conductorName': 'Hill, Ureli Corelli',
#      'soloists': [{'soloistName': 'Otto, Antoinette',
#        'soloistInstrument': 'Soprano',
#        'soloistRoles': 'S'}]},
#     {'ID': '3784*',
#      'composerName': 'Hummel,  Johann',
#      'workTitle': "GRAND PIANO FANTASIA (OBERON'S ZAUBERHORN)",
#      'conductorName': 'Hill, Ureli Corelli',
#      'soloists': [{'soloistName': 'Timm, Henry C.',
#        'soloistInstrument': 'Piano',
#        'soloistRoles': 'S'}]},
#     {'ID': '3789*1',
#      'composerName': 'Meyerbeer,  Giacomo',
#      'workTitle': 'CROCIATO IN EGITTO, IL',
#      'movement': '"Eccomi, giunto omai," Armando (Scena e Cavatina)',
#      'conductorName': 'Hill, Ureli Corelli',
#      'soloists': [{'soloistName': 'Otto, Antoinette',
#        'soloistInstrument': 'Soprano',
#        'soloistRoles': 'S'}]},
#     {'ID': '8834*3',
#      'composerName': 'Weber,  Carl  Maria Von',
#      'workTitle': 'OBERON',
#      'movement': 'Overture',
#      'conductorName': 'Hill, Ureli Corelli',
#      'soloists': []}]},
#   {'id': '51ee4702-8f57-4fea-8314-24ae20a2a83f-0.1',
#    'programID': '4919',
#    'orchestra': 'New York Philharmonic',
#    'season': '1845-46',
#    'concerts': [{'eventType': 'Subscription Season',
#      'Location': 'Manhattan, NY',
#      'Venue': 'Apollo Rooms',
#      'Date': '1845-11-22T05:00:00Z',
#      'Time': '8:00PM'}],
#    'works': [{'ID': '52575*',
#      'composerName': 'Mendelssohn,  Felix',
#      'workTitle': 'SYMPHONY NO. 3, A MINOR, OP.56 (SCOTTISH)',
#      'conductorName': 'Loder, George',
#      'soloists': []},
#     {'ID': '0*', 'interval': 'Intermission', 'soloists': []},
#     {'ID': '1965*1',
#      'composerName': 'Cherubini,  Luigi',
#      'workTitle': "ANACRÉON, OU L'AMOUR FUGITIF",
#      'movement': 'Overture',
#      'conductorName': 'Loder, George',
#      'soloists': []},
#     {'ID': '3791*1',
#      'composerName': 'Mercadante,  Giuseppe  Saverio',
#      'workTitle': 'NITOCRI',
#      'movement': '"Se m\'abbandoni," (cavatina)',
#      'conductorName': 'Loder, George',
#      'soloists': [{'soloistName': 'Mott',
#        'soloistInstrument': 'Vocalist',
#        'soloistRoles': 'S'}]},
#     {'ID': '3795*',
#      'composerName': 'Traditional,',
#      'workTitle': 'SOLO, HARP',
#      'conductorName': 'Loder, George',
#      'soloists': [{'soloistName': 'Lazare, Jenny',
#        'soloistInstrument': 'Harp',
#        'soloistRoles': 'S'}]},
#     {'ID': '53076*1',
#      'composerName': 'Rossini,  Gioachino',
#      'workTitle': 'STABAT MATER',
#      'movement': 'Fac ut Portem Christi mortem (Cavatina)',
#      'conductorName': 'Loder, George',
#      'soloists': [{'soloistName': 'Mott',
#        'soloistInstrument': 'Vocalist',
#        'soloistRoles': 'S'}]},
#     {'ID': '3808*',
#      'composerName': 'Heller,  Stephen [István]',
#      'workTitle': 'FANTASIA ON THEMES FROM OPERA, CHARLES VI',
#      'conductorName': 'Loder, George',
#      'soloists': [{'soloistName': 'Wollenhauft, Hermann',
#        'soloistInstrument': 'Piano',
#        'soloistRoles': 'S'}]},
#     {'ID': '3810*1',
#      'composerName': 'Mehul [Méhul],  Etienne  Nicolas',
#      'workTitle': 'DE LA CHASSE DU JEUNE HENRI',
#      'movement': 'Overture',
#      'conductorName': 'Loder, George',
#      'soloists': []}]},
#   {'id': '1b162182-4605-4cbe-9fa8-61536b60171a-0.1',
#    'programID': '562',
#    'orchestra': 'New York Philharmonic',
#    'season': '1845-46',
#    'concerts': [{'eventType': 'Subscription Season',
#      'Location': 'Manhattan, NY',
#      'Venue': 'Apollo Rooms',
#      'Date': '1846-01-17T05:00:00Z',
#      'Time': '8:00PM'}],
#    'works': [{'ID': '52446*',
#      'composerName': 'Beethoven,  Ludwig  van',
#      'workTitle': 'SYMPHONY NO. 5 IN C MINOR, OP.67',
#      'conductorName': 'Hill, Ureli Corelli',
#      'soloists': []},
#     {'ID': '0*', 'interval': 'Intermission', 'soloists': []},
#     {'ID': '3813*',
#      'composerName': 'Loder,  George, Jr.',
#      'workTitle': 'MARMION',
#      'conductorName': 'Loder, George',
#      'soloists': []},
#     {'ID': '52492*',
#      'composerName': 'Mendelssohn,  Felix',
#      'workTitle': 'CONCERTO, PIANO, NO. 1, G MINOR, OP.25',
#      'conductorName': 'Hill, Ureli Corelli',
#      'soloists': [{'soloistName': 'Timm, Henry C.',
#        'soloistInstrument': 'Piano',
#        'soloistRoles': 'S'}]},
#     {'ID': '3764*',
#      'composerName': 'Lindpaintner,  Peter  Von',
#      'workTitle': 'SINFONIA CONCERTANTE NO. 2',
#      'soloists': [{'soloistName': 'Kyle, John A.',
#        'soloistInstrument': 'Flute',
#        'soloistRoles': 'A'},
#       {'soloistName': 'Starck, Frederick',
#        'soloistInstrument': 'Clarinet',
#        'soloistRoles': 'A'},
#       {'soloistName': 'Wiese, Frederick',
#        'soloistInstrument': 'Oboe',
#        'soloistRoles': 'A'},
#       {'soloistName': 'Trojsi, Gaetano',
#        'soloistInstrument': 'French Horn',
#        'soloistRoles': 'A'},
#       {'soloistName': 'Reiff, Anton, Sr.',
#        'soloistInstrument': 'Bassoon',
#        'soloistRoles': 'A'}]},
#     {'ID': '3818*',
#      'composerName': 'Beriot,  Charles-Auguste  de',
#      'workTitle': 'CONCERTO, VIOLIN, NO. 4, OP. 46',
#      'conductorName': 'Hill, Ureli Corelli',
#      'soloists': [{'soloistName': 'Burke, Joseph',
#        'soloistInstrument': 'Violin',
#        'soloistRoles': 'S'}]},
#     {'ID': '3823*',
#      'composerName': 'Reissiger,  Karl  Gottlieb',
#      'workTitle': 'CONCERT OVERTURE, OP. 128',
#      'conductorName': 'Hill, Ureli Corelli',
#      'soloists': []}]},
#   {'id': '66cc492e-e6eb-42e6-abe5-b370a8f4994b-0.1',
#    'programID': '1408',
#    'orchestra': 'New York Philharmonic',
#    'season': '1845-46',
#    'concerts': [{'eventType': 'Subscription Season',
#      'Location': 'Manhattan, NY',
#      'Venue': 'Apollo Rooms',
#      'Date': '1846-03-07T05:00:00Z',
#      'Time': '8:00PM'}],
#    'works': [{'ID': '3826*',
#      'composerName': 'Kalliwoda,  Johann  W.',
#      'workTitle': 'SYMPHONY NO. 1',
#      'conductorName': 'Boucher, Alfred',
#      'soloists': []},
#     {'ID': '3839*',
#      'composerName': 'Cherubini,  Luigi',
#      'workTitle': 'AVE MARIA',
#      'conductorName': 'Boucher, Alfred',
#      'soloists': [{'soloistName': 'Northall, Julia',
#        'soloistInstrument': 'Vocalist',
#        'soloistRoles': 'S'}]},
#     {'ID': '0*', 'interval': 'Intermission', 'soloists': []},
#     {'ID': '9187*1',
#      'composerName': 'Weber,  Carl  Maria Von',
#      'workTitle': 'EURYANTHE, OP. 81, J. 291',
#      'movement': 'Overture',
#      'conductorName': 'Boucher, Alfred',
#      'soloists': []},
#     {'ID': '53080*3',
#      'composerName': 'Rossini,  Gioachino',
#      'workTitle': 'TANCREDI',
#      'movement': 'Cavatina [unspecified]',
#      'conductorName': 'Boucher, Alfred',
#      'soloists': [{'soloistName': 'Northall, Julia',
#        'soloistInstrument': 'Vocalist',
#        'soloistRoles': 'S'}]},
#     {'ID': '51668*2',
#      'composerName': 'Mozart,  Wolfgang  Amadeus',
#      'workTitle': 'SYMPHONY NO. 41, C MAJOR, K.551, "JUPITER"',
#      'movement': 'Andante cantabile',
#      'conductorName': 'Boucher, Alfred',
#      'soloists': []},
#     {'ID': '3842*',
#      'composerName': 'Furstenau,  Anton  Bernhard',
#      'workTitle': 'CONCERTO, FLUTE, NO. 5, OP.52',
#      'conductorName': 'Boucher, Alfred',
#      'soloists': [{'soloistName': 'Kyle, John A.',
#        'soloistInstrument': 'Flute',
#        'soloistRoles': 'S'}]},
#     {'ID': '2273*',
#      'composerName': 'Berlioz,  Hector',
#      'workTitle': 'FRANCS-JUGES, LES: OVERTURE',
#      'conductorName': 'Boucher, Alfred',
#      'soloists': []}]},
#   {'id': '08205151-c17b-4de8-ae6e-c45bf72921e0-0.1',
#    'programID': '1851',
#    'orchestra': 'New York Philharmonic',
#    'season': '1845-46',
#    'concerts': [{'eventType': 'Subscription Season',
#      'Location': 'Manhattan, NY',
#      'Venue': 'Apollo Rooms',
#      'Date': '1846-04-25T05:00:00Z',
#      'Time': '8:00PM'}],
#    'works': [{'ID': '51664*',
#      'composerName': 'Mozart,  Wolfgang  Amadeus',
#      'workTitle': 'SYMPHONY NO. 40, G MINOR, K.550',
#      'conductorName': 'Timm, Henry C.',
#      'soloists': []},
#     {'ID': '5801*1',
#      'composerName': 'Mendelssohn,  Felix',
#      'workTitle': "MIDSUMMER NIGHT'S DREAM, OP. 61",
#      'movement': 'Overture',
#      'conductorName': 'Timm, Henry C.',
#      'soloists': []},
#     {'ID': '0*', 'interval': 'Intermission', 'soloists': []},
#     {'ID': '52449*',
#      'composerName': 'Beethoven,  Ludwig  van',
#      'workTitle': 'SYMPHONY NO. 6 IN F MAJOR, OP.68 (PASTORAL)',
#      'conductorName': 'Timm, Henry C.',
#      'soloists': []},
#     {'ID': '3849*',
#      'composerName': 'Traditional,',
#      'workTitle': 'DUETTO, TWO CORNETS',
#      'conductorName': 'Timm, Henry C.',
#      'soloists': [{'soloistName': 'Dodworth, Allen',
#        'soloistInstrument': 'Cornet',
#        'soloistRoles': 'S'},
#       {'soloistName': 'Dodworth, Harvey B.',
#        'soloistInstrument': 'Cornet',
#        'soloistRoles': 'S'}]},
#     {'ID': '3453*1',
#      'composerName': 'Rossini,  Gioachino',
#      'workTitle': 'GAZZA LADRA, LA',
#      'movement': 'Overture',
#      'conductorName': 'Timm, Henry C.',
#      'soloists': []}]},
#   {'id': '079d4d73-e2e7-4c8b-9ab6-294cab67d9de-0.1',
#    'programID': '2321',
#    'orchestra': 'New York Philharmonic',
#    'season': '1845-46',
#    'concerts': [{'eventType': 'Special',
#      'Location': 'Manhattan, NY',
#      'Venue': 'Castle Garden',
#      'Date': '1846-05-20T05:00:00Z',
#      'Time': 'None'}],
#    'works': [{'ID': '6709*16',
#      'composerName': 'Weber,  Carl  Maria Von',
#      'workTitle': 'FREISCHUTZ, DER',
#      'movement': 'Overture',
#      'conductorName': 'Hill, Ureli Corelli',
#      'soloists': []},
#     {'ID': '3512*2',
#      'composerName': 'Donizetti,  Gaetano',
#      'workTitle': 'ANNA BOLENA',
#      'movement': '"Per questa fiamma indomita," Giovanna (aria)',
#      'conductorName': 'Hill, Ureli Corelli',
#      'soloists': [{'soloistName': 'Northall, Julia',
#        'soloistInstrument': 'Vocalist',
#        'soloistRoles': 'S'}]},
#     {'ID': '8955*1',
#      'composerName': 'Mozart,  Wolfgang  Amadeus',
#      'workTitle': 'MAGIC FLUTE, THE, K.620',
#      'movement': 'Overture',
#      'conductorName': 'Hill, Ureli Corelli',
#      'soloists': []},
#     {'ID': '3857*1',
#      'composerName': 'Donizetti,  Gaetano',
#      'workTitle': 'FALIERO',
#      'movement': "''Tutto or morte,'' Elena (aria)",
#      'conductorName': 'Hill, Ureli Corelli',
#      'soloists': [{'soloistName': 'Otto, Antoinette',
#        'soloistInstrument': 'Soprano',
#        'soloistRoles': 'S'}]},
#     {'ID': '52492*',
#      'composerName': 'Mendelssohn,  Felix',
#      'workTitle': 'CONCERTO, PIANO, NO. 1, G MINOR, OP.25',
#      'conductorName': 'Hill, Ureli Corelli',
#      'soloists': [{'soloistName': 'Timm, Henry C.',
#        'soloistInstrument': 'Piano',
#        'soloistRoles': 'S'}]},
#     {'ID': '3860*2',
#      'composerName': 'Verdi,  Giuseppe',
#      'workTitle': 'LOMBARDI, I',
#      'movement': '"Non fu sogno," Giselda (aria), Part IV',
#      'conductorName': 'Hill, Ureli Corelli',
#      'soloists': [{'soloistName': 'Pico',
#        'soloistInstrument': 'Vocalist',
#        'soloistRoles': 'S'},
#       {'soloistName': 'Beames',
#        'soloistInstrument': 'Piano',
#        'soloistRoles': 'A'}]},
#     {'ID': '50729*',
#      'composerName': 'Weber,  Carl  Maria Von',
#      'workTitle': 'JUBEL OVERTURE, OP. 59',
#      'conductorName': 'Hill, Ureli Corelli',
#      'soloists': []},
#     {'ID': '0*', 'interval': 'Intermission', 'soloists': []},
#     {'ID': '52461*',
#      'composerName': 'Beethoven,  Ludwig  van',
#      'workTitle': 'SYMPHONY NO. 9 IN D MINOR, OP.125',
#      'conductorName': 'Loder, George',
#      'soloists': [{'soloistName': 'Otto, Antoinette',
#        'soloistInstrument': 'Soprano',
#        'soloistRoles': 'S'},
#       {'soloistName': 'Boulard',
#        'soloistInstrument': 'Alto',
#        'soloistRoles': 'S'},
#       {'soloistName': 'Munson',
#        'soloistInstrument': 'Tenor',
#        'soloistRoles': 'S'},
#       {'soloistName': 'Mayer',
#        'soloistInstrument': 'Bass',
#        'soloistRoles': 'S'}]}]},
#   {'id': 'f679abf1-6beb-4087-b9c4-3b2a3fef3457-0.1',
#    'programID': '3540',
#    'orchestra': 'New York Philharmonic',
#    'season': '1846-47',
#    'concerts': [{'eventType': 'Subscription Season',
#      'Location': 'Manhattan, NY',
#      'Venue': 'Apollo Rooms',
#      'Date': '1846-11-21T05:00:00Z',
#      'Time': '8:00PM'}],
#    'works': [{'ID': '3864*',
#      'composerName': 'Spohr,  Louis',
#      'workTitle': 'SYMPHONY NO. 4, OP. 86 (DIE WEIHE DER TONE)',
#      'conductorName': 'Loder, George',
#      'soloists': []},
#     {'ID': '0*', 'interval': 'Intermission', 'soloists': []},
#     {'ID': '3823*',
#      'composerName': 'Reissiger,  Karl  Gottlieb',
#      'workTitle': 'CONCERT OVERTURE, OP. 128',
#      'conductorName': 'Loder, George',
#      'soloists': []},
#     {'ID': '1587*',
#      'composerName': 'Chopin,  Frédéric',
#      'workTitle': 'CONCERTO, PIANO, NO. 1, E MINOR, OP. 11',
#      'conductorName': 'Loder, George',
#      'soloists': [{'soloistName': 'Timm, Henry C.',
#        'soloistInstrument': 'Piano',
#        'soloistRoles': 'S'}]},
#     {'ID': '2345*',
#      'composerName': 'Berlioz,  Hector',
#      'workTitle': 'KING LEAR OVERTURE, OP. 4',
#      'conductorName': 'Loder, George',
#      'soloists': []}]},
#   {'id': '111c22e5-0527-4e1c-b498-bc494246aca8-0.1',
#    'programID': '6573',
#    'orchestra': 'New York Philharmonic',
#    'season': '1846-47',
#    'concerts': [{'eventType': 'Subscription Season',
#      'Location': 'Manhattan, NY',
#      'Venue': 'Apollo Rooms',
#      'Date': '1847-01-09T05:00:00Z',
#      'Time': '8:00PM'}],
#    'works': [{'ID': '51658*',
#      'composerName': 'Mozart,  Wolfgang  Amadeus',
#      'workTitle': 'SYMPHONY NO. 39, E-FLAT MAJOR, K.543',
#      'conductorName': 'Timm, Henry C.',
#      'soloists': []},
#     {'ID': '3867*5',
#      'composerName': 'Meyerbeer,  Giacomo',
#      'workTitle': 'ROBERT LE DIABLE',
#      'movement': '"Robert, toi que j\'aime," Isabelle (cavatina), Act IV',
#      'conductorName': 'Timm, Henry C.',
#      'soloists': [{'soloistName': 'Ablamowicz, Anna',
#        'soloistInstrument': 'Vocalist',
#        'soloistRoles': 'S'}]},
#     {'ID': '3871*',
#      'composerName': 'Bristow,  George  Frederick',
#      'workTitle': 'CONCERT OVERTURE, OP.3',
#      'conductorName': 'Timm, Henry C.',
#      'soloists': []},
#     {'ID': '0*', 'interval': 'Intermission', 'soloists': []},
#     {'ID': '52449*',
#      'composerName': 'Beethoven,  Ludwig  van',
#      'workTitle': 'SYMPHONY NO. 6 IN F MAJOR, OP.68 (PASTORAL)',
#      'conductorName': 'Timm, Henry C.',
#      'soloists': []},
#     {'ID': '3700*2',
#      'composerName': 'Bellini,  Vincenzo',
#      'workTitle': 'LA SONNAMBULA',
#      'movement': '"Care Compagne... Come per me serena," Amina (recitative and cavatina)',
#      'conductorName': 'Timm, Henry C.',
#      'soloists': [{'soloistName': 'Ablamowicz, Anna',
#        'soloistInstrument': 'Vocalist',
#        'soloistRoles': 'S'}]},
#     {'ID': '8319*',
#      'composerName': 'Spohr,  Louis',
#      'workTitle': 'CONCERTO, VIOLIN, NO. 12, A MAJOR, OP. 79 (CONCERTINO NO. 1)',
#      'conductorName': 'Timm, Henry C.',
#      'soloists': [{'soloistName': 'Heuckeroth, Charles',
#        'soloistInstrument': 'Violin',
#        'soloistRoles': 'S'}]},
#     {'ID': '6709*16',
#      'composerName': 'Weber,  Carl  Maria Von',
#      'workTitle': 'FREISCHUTZ, DER',
#      'movement': 'Overture',
#      'conductorName': 'Timm, Henry C.',
#      'soloists': []}]},
#   {'id': '07ffca52-b177-43c2-aa6b-ee09f4a0ea4b-0.1',
#    'programID': '47',
#    'orchestra': 'New York Philharmonic',
#    'season': '1846-47',
#    'concerts': [{'eventType': 'Subscription Season',
#      'Location': 'Manhattan, NY',
#      'Venue': 'Apollo Rooms',
#      'Date': '1847-03-06T05:00:00Z',
#      'Time': '8:00PM'}],
#    'works': [{'ID': '52453*',
#      'composerName': 'Beethoven,  Ludwig  van',
#      'workTitle': 'SYMPHONY NO. 7 IN A MAJOR, OP.92',
#      'conductorName': 'Boucher, Alfred',
#      'soloists': []},
#     {'ID': '0*', 'interval': 'Intermission', 'soloists': []},
#     {'ID': '3745*1',
# ...
#     {'ID': '9001*12',
#      'composerName': 'Wagner,  Richard',
#      'workTitle': 'WALKURE, DIE, WWV 86B',
#      'movement': 'Ride of the Valkyries, Act III',
#      'conductorName': 'Mahler, Gustav',
#      'soloists': []},
#     {'ID': '9001*9',
#      'composerName': 'Wagner,  Richard',
#      'workTitle': 'WALKURE, DIE, WWV 86B',
#      'movement': 'Magic Fire Music, Act III, scene iii',
#      'conductorName': 'Mahler, Gustav',
#      'soloists': []}]},
#   {'id': 'd265f87e-91ca-47ef-8810-96056d36bcb7-0.1',
#    'programID': '14724',
#    'orchestra': 'New York Symphony',
#    'season': '1910-11',
#    'concerts': [{'eventType': 'Tour',
#      'Location': 'Pittsburgh, PA',
#      'Venue': 'Carnegie Music Hall',
#      'Date': '1911-01-27T05:00:00Z',
#      'Time': 'None'}],
#    'works': [{'ID': '53215*',
#      'composerName': 'Dvorak,  Antonín',
#      'workTitle': 'CARNIVAL OVERTURE, OP.92',
#      'conductorName': 'Damrosch, Walter',
#      'soloists': []},
#     {'ID': '51664*',
#      'composerName': 'Mozart,  Wolfgang  Amadeus',
#      'workTitle': 'SYMPHONY NO. 40, G MINOR, K.550',
#      'conductorName': 'Damrosch, Walter',
#      'soloists': []},
#     {'ID': '13432*',
#      'composerName': 'Walmisley,  Thomas  Attwood',
#      'workTitle': 'MUSIC, ALL POWERFUL',
#      'conductorName': 'Damrosch, Walter',
#      'soloists': []},
#     {'ID': '13433*',
#      'composerName': 'Kremser,  Eduard',
#      'workTitle': 'ROMANCE OF THE RHINE',
#      'conductorName': 'Damrosch, Walter',
#      'soloists': []},
#     {'ID': '13434*',
#      'composerName': 'Mendelssohn,  Felix',
#      'workTitle': 'AH! WERE I ON YONDER PLAIN',
#      'conductorName': 'Damrosch, Walter',
#      'soloists': []},
#     {'ID': '13435*',
#      'composerName': 'Wagner,  Richard',
#      'workTitle': 'PARSIFAL, PROCESSION OF THE KNIGHTS OF THE HOLY GRAIL',
#      'conductorName': 'Damrosch, Walter',
#      'soloists': []},
#     {'ID': '13436*',
#      'composerName': 'Dard,  Antoine',
#      'workTitle': 'NIGHT AND DAY',
#      'conductorName': 'Damrosch, Walter',
#      'soloists': []},
#     {'ID': '13437*',
#      'composerName': 'Bridge,  Frederick',
#      'workTitle': 'BOLD TURPIN',
#      'conductorName': 'Damrosch, Walter',
#      'soloists': []},
#     {'ID': '13438*',
#      'composerName': 'Goetz,  Hermann',
#      'workTitle': 'THE WATER LILY',
#      'conductorName': 'Damrosch, Walter',
#      'soloists': []}]},
#   {'id': 'b99a50ad-1ad7-4b6f-8aed-23c1b41c494d-0.1',
#    'programID': '10487',
#    'orchestra': 'New York Symphony',
#    'season': '1910-11',
#    'concerts': [{'eventType': 'Subscription Season',
#      'Location': 'Manhattan, NY',
#      'Venue': 'Century Theatre',
#      'Date': '1911-01-28T05:00:00Z',
#      'Time': '3:00PM'}],
#    'works': [{'ID': '5796*',
#      'composerName': 'Enesco,  Georges',
#      'workTitle': 'SYMPHONY NO. 1, E FLAT MAJOR, OP. 13',
#      'conductorName': 'Damrosch, Walter',
#      'soloists': []},
#     {'ID': '0*', 'interval': 'Intermission', 'soloists': []},
#     {'ID': '2068*',
#      'composerName': 'Beethoven,  Ludwig  van',
#      'workTitle': 'CONCERTO, VIOLIN, D MAJOR, OP.61',
#      'conductorName': 'Damrosch, Walter',
#      'soloists': [{'soloistName': 'Zimbalist, Efrem',
#        'soloistInstrument': 'Violin',
#        'soloistRoles': 'S'}]},
#     {'ID': '2891*',
#      'composerName': 'Hadley,  Henry  Kimball',
#      'workTitle': 'CULPRIT FAY RHAPSODY, OP. 62',
#      'conductorName': 'Damrosch, Walter',
#      'soloists': []}]},
#   {'id': 'cb11a157-0b0c-4cba-8e1c-4f285703d522-0.1',
#    'programID': '1276',
#    'orchestra': 'New York Philharmonic',
#    'season': '1910-11',
#    'concerts': [{'eventType': 'Subscription Season',
#      'Location': 'Manhattan, NY',
#      'Venue': 'Carnegie Hall',
#      'Date': '1911-01-31T05:00:00Z',
#      'Time': '8:15PM'},
#     {'eventType': 'Subscription Season',
#      'Location': 'Manhattan, NY',
#      'Venue': 'Carnegie Hall',
#      'Date': '1911-02-03T05:00:00Z',
#      'Time': '2:30PM'}],
#    'works': [{'ID': '4945*',
#      'composerName': 'Mendelssohn,  Felix',
#      'workTitle': 'MELUSINE: OVERTURE',
#      'conductorName': 'Mahler, Gustav',
#      'soloists': []},
#     {'ID': '53072*',
#      'composerName': 'Schumann,  Robert',
#      'workTitle': 'SYMPHONY NO. 3, E FLAT MAJOR, OP. 97 (RHENISH)',
#      'conductorName': 'Mahler, Gustav',
#      'soloists': []},
#     {'ID': '0*', 'interval': 'Intermission', 'soloists': []},
#     {'ID': '8999*1',
#      'composerName': 'Wagner,  Richard',
#      'workTitle': 'LOHENGRIN',
#      'movement': 'Act I: Prelude',
#      'conductorName': 'Mahler, Gustav',
#      'soloists': []},
#     {'ID': '51497*',
#      'composerName': 'Bizet,  Georges',
#      'workTitle': 'ROMA, SUITE, NO. 3',
#      'conductorName': 'Mahler, Gustav',
#      'soloists': []}]},
#   {'id': 'd8917db1-fbe7-4ddc-835a-ee755ad05246-0.1',
#    'programID': '8289',
#    'orchestra': 'New York Symphony',
#    'season': '1910-11',
#    'concerts': [{'eventType': 'Subscription Season',
#      'Location': 'Manhattan, NY',
#      'Venue': 'New Theatre',
#      'Date': '1911-02-05T05:00:00Z',
#      'Time': '3:00PM'}],
#    'works': [{'ID': '2344*',
#      'composerName': 'Bach,  Johann  Sebastian',
#      'workTitle': 'BRANDENBURG CONCERTO NO. 1, F MAJOR, BWV 1046',
#      'conductorName': 'Damrosch, Walter',
#      'soloists': [{'soloistName': 'Mannes, David',
#        'soloistInstrument': 'Violin',
#        'soloistRoles': 'S'}]},
#     {'ID': '0*', 'interval': 'Intermission', 'soloists': []},
#     {'ID': '53200*',
#      'composerName': 'Dukas,  Paul',
#      'workTitle': 'SYMPHONY, C MAJOR',
#      'conductorName': 'Damrosch, Walter',
#      'soloists': []},
#     {'ID': '3296*',
#      'composerName': 'Franck,  César',
#      'workTitle': 'SYMPHONIC VARIATIONS',
#      'conductorName': 'Damrosch, Walter',
#      'soloists': [{'soloistName': 'Borchard, Adolphe',
#        'soloistInstrument': 'Piano',
#        'soloistRoles': 'S'}]}]},
#   {'id': 'b81cab3a-bdca-4fbf-b518-2cdcf38efe05-0.1',
#    'programID': '5635',
#    'orchestra': 'New York Philharmonic',
#    'season': '1910-11',
#    'concerts': [{'eventType': 'Subscription Season',
#      'Location': 'Manhattan, NY',
#      'Venue': 'Carnegie Hall',
#      'Date': '1911-02-05T05:00:00Z',
#      'Time': '3:00PM'}],
#    'works': [{'ID': '50964*1',
#      'composerName': 'Lalo,  Edouard',
#      'workTitle': "ROI D'YS, LE",
#      'movement': 'Overture',
#      'conductorName': 'Mahler, Gustav',
#      'soloists': []},
#     {'ID': '2819*',
#      'composerName': 'Schubert,  Franz',
#      'workTitle': 'SYMPHONY NO. 8, B MINOR, D.759 (UNFINISHED)',
#      'conductorName': 'Mahler, Gustav',
#      'soloists': []},
#     {'ID': '52608*',
#      'composerName': 'MacDowell,  Edward  A.',
#      'workTitle': 'CONCERTO, PIANO, NO. 2, D MINOR, OP. 23',
#      'conductorName': 'Mahler, Gustav',
#      'soloists': [{'soloistName': 'Hutcheson, Ernest',
#        'soloistInstrument': 'Piano',
#        'soloistRoles': 'S'}]},
#     {'ID': '0*', 'interval': 'Intermission', 'soloists': []},
#     {'ID': '8868*1',
#      'composerName': 'Wagner,  Richard',
#      'workTitle': 'FLIEGENDE HOLLANDER [HOLLÄNDER], DER',
#      'movement': 'Overture',
#      'conductorName': 'Mahler, Gustav',
#      'soloists': []},
#     {'ID': '9005*7',
#      'composerName': 'Wagner,  Richard',
#      'workTitle': 'SIEGFRIED, WWV 86C',
#      'movement': 'Waldweben (Forest Murmurs)',
#      'conductorName': 'Mahler, Gustav',
#      'soloists': []},
#     {'ID': '9007*17',
#      'composerName': 'Wagner,  Richard',
#      'workTitle': 'MEISTERSINGER, DIE, WWV 96',
#      'movement': 'Prelude to Act I',
#      'conductorName': 'Mahler, Gustav',
#      'soloists': []}]},
#   {'id': '9548c311-0c8f-4a43-afbd-bc637e7d505e-0.1',
#    'programID': '5638',
#    'orchestra': 'New York Philharmonic',
#    'season': '1910-11',
#    'concerts': [{'eventType': 'Subscription Season',
#      'Location': 'Manhattan, NY',
#      'Venue': 'Carnegie Hall',
#      'Date': '1911-02-07T05:00:00Z',
#      'Time': '8:15PM'},
#     {'eventType': 'Subscription Season',
#      'Location': 'Manhattan, NY',
#      'Venue': 'Carnegie Hall',
#      'Date': '1911-02-10T05:00:00Z',
#      'Time': '2:30PM'}],
#    'works': [{'ID': '51356*5',
#      'composerName': 'Berlioz,  Hector',
#      'workTitle': 'ROMEO ET JULIETTE, OP.17',
#      'movement': "Romeo Alone - Sadness - Distant sounds of music and dancing - Great festivities in Capulet's palace (Ball Scene)",
#      'conductorName': 'Mahler, Gustav',
#      'soloists': []},
#     {'ID': '51356*6',
#      'composerName': 'Berlioz,  Hector',
#      'workTitle': 'ROMEO ET JULIETTE, OP.17',
#      'movement': "Star-lit night - Capulet's garden, silent and deserted - The young Capulets, leaving the hall, pass by singing fragements of the dance music (Love scene, Adagio)",
#      'conductorName': 'Mahler, Gustav',
#      'soloists': []},
#     {'ID': '51356*7',
#      'composerName': 'Berlioz,  Hector',
#      'workTitle': 'ROMEO ET JULIETTE, OP.17',
#      'movement': 'Queen Mab, or the Fairy of dreams (Scherzo)',
#      'conductorName': 'Mahler, Gustav',
#      'soloists': []},
#     {'ID': '9007*15',
#      'composerName': 'Wagner,  Richard',
#      'workTitle': 'MEISTERSINGER, DIE, WWV 96',
#      'movement': 'Act III: Prelude',
#      'conductorName': 'Mahler, Gustav',
#      'soloists': []},
#     {'ID': '9007*1',
#      'composerName': 'Wagner,  Richard',
#      'workTitle': 'MEISTERSINGER, DIE, WWV 96',
#      'movement': '"Wahn! Wahn!" Sachs (monologue), Act III, scene i',
#      'conductorName': 'Mahler, Gustav',
#      'soloists': [{'soloistName': 'Bispham, David Scull',
#        'soloistInstrument': 'Baritone',
#        'soloistRoles': 'S'}]},
#     {'ID': '6401*4',
#      'composerName': 'Strauss,  Richard',
#      'workTitle': 'SONGS, FOUR (VIER LIEDER), OP. 33, (ORCHESTRA)',
#      'movement': {'em': 'Pilgers Morgenlied'},
#      'conductorName': 'Mahler, Gustav',
#      'soloists': [{'soloistName': 'Bispham, David Scull',
#        'soloistInstrument': 'Baritone',
#        'soloistRoles': 'S'}]},
#     {'ID': '0*', 'interval': 'Intermission', 'soloists': []},
#     {'ID': '52453*',
#      'composerName': 'Beethoven,  Ludwig  van',
#      'workTitle': 'SYMPHONY NO. 7 IN A MAJOR, OP.92',
#      'conductorName': 'Mahler, Gustav',
#      'soloists': []}]},
#   {'id': '230102ce-2ec7-4038-b6dd-c740c9171992-0.1',
#    'programID': '8291',
#    'orchestra': 'New York Symphony',
#    'season': '1910-11',
#    'concerts': [{'eventType': 'Subscription Season',
#      'Location': 'Manhattan, NY',
#      'Venue': 'New Theatre',
#      'Date': '1911-02-12T05:00:00Z',
#      'Time': '3:00PM'}],
#    'works': [{'ID': '6709*16',
#      'composerName': 'Weber,  Carl  Maria Von',
#      'workTitle': 'FREISCHUTZ, DER',
#      'movement': 'Overture',
#      'conductorName': 'Damrosch, Walter',
#      'soloists': []},
#     {'ID': '52313*',
#      'composerName': 'Chausson,  Ernest',
#      'workTitle': 'SYMPHONY IN B FLAT MAJOR, OP. 20',
#      'conductorName': 'Damrosch, Walter',
#      'soloists': []},
#     {'ID': '0*', 'interval': 'Intermission', 'soloists': []},
#     {'ID': '3908*',
#      'composerName': 'Chausson,  Ernest',
#      'workTitle': 'POEME, OP.25 (VIOLIN + ORCH)',
#      'conductorName': 'Damrosch, Walter',
#      'soloists': [{'soloistName': 'Saslavsky, Alexander',
#        'soloistInstrument': 'Violin',
#        'soloistRoles': 'S'}]},
#     {'ID': '50010*',
#      'composerName': 'Tchaikovsky,  Pyotr  Ilyich',
#      'workTitle': 'SUITE NO. 4, G MAJOR, OP. 61, "MOZARTIANA"',
#      'conductorName': 'Damrosch, Walter',
#      'soloists': []}]},
#   {'id': '3ac3b545-d8c9-41b3-a677-90b569865267-0.1',
#    'programID': '5643',
#    'orchestra': 'New York Philharmonic',
#    'season': '1910-11',
#    'concerts': [{'eventType': 'Subscription Season',
#      'Location': 'Brooklyn, NY',
#      'Venue': 'Brooklyn Academy of Music',
#      'Date': '1911-02-12T05:00:00Z',
#      'Time': '3:00PM'}],
#    'works': [{'ID': '8834*3',
#      'composerName': 'Weber,  Carl  Maria Von',
#      'workTitle': 'OBERON',
#      'movement': 'Overture',
#      'conductorName': 'Mahler, Gustav',
#      'soloists': []},
#     {'ID': '50070*',
#      'composerName': 'Tchaikovsky,  Pyotr  Ilyich',
#      'workTitle': 'SYMPHONY NO. 6, B MINOR, OP. 74 (PATHÉTIQUE)',
#      'conductorName': 'Mahler, Gustav',
#      'soloists': []},
#     {'ID': '0*', 'interval': 'Intermission', 'soloists': []},
#     {'ID': '9007*15',
#      'composerName': 'Wagner,  Richard',
#      'workTitle': 'MEISTERSINGER, DIE, WWV 96',
#      'movement': 'Act III: Prelude',
#      'conductorName': 'Mahler, Gustav',
#      'soloists': []},
#     {'ID': '9007*1',
#      'composerName': 'Wagner,  Richard',
#      'workTitle': 'MEISTERSINGER, DIE, WWV 96',
#      'movement': '"Wahn! Wahn!" Sachs (monologue), Act III, scene i',
#      'conductorName': 'Mahler, Gustav',
#      'soloists': [{'soloistName': 'Bispham, David Scull',
#        'soloistInstrument': 'Baritone',
#        'soloistRoles': 'S'}]},
#     {'ID': '6401*4',
#      'composerName': 'Strauss,  Richard',
#      'workTitle': 'SONGS, FOUR (VIER LIEDER), OP. 33, (ORCHESTRA)',
#      'movement': {'em': 'Pilgers Morgenlied'},
#      'conductorName': 'Mahler, Gustav',
#      'soloists': [{'soloistName': 'Bispham, David Scull',
#        'soloistInstrument': 'Baritone',
#        'soloistRoles': 'S'}]},
#     {'ID': '51149*',
#      'composerName': 'Liszt,  Franz',
#      'workTitle': 'PRELUDES, LES (SYMPHONIC POEM NO. 3)',
#      'conductorName': 'Mahler, Gustav',
#      'soloists': []}]},
#   {'id': '04702b2a-e308-4980-94a9-6627c9e41b68-0.1',
#    'programID': '5648',
#    'orchestra': 'New York Philharmonic',
#    'season': '1910-11',
#    'concerts': [{'eventType': 'Subscription Season',
#      'Location': 'Manhattan, NY',
#      'Venue': 'Carnegie Hall',
#      'Date': '1911-02-14T05:00:00Z',
#      'Time': '8:15PM'},
#     {'eventType': 'Subscription Season',
#      'Location': 'Manhattan, NY',
#      'Venue': 'Carnegie Hall',
#      'Date': '1911-02-17T05:00:00Z',
#      'Time': '2:30PM'}],
#    'works': [{'ID': '52273*',
#      'composerName': 'Chadwick,  George  Whitefield',
#      'workTitle': 'MELPOMENE',
#      'conductorName': 'Mahler, Gustav',
#      'soloists': []},
#     {'ID': '6318*',
#      'composerName': 'Stanford,  Sir  Charles  Villiers',
#      'workTitle': 'SYMPHONY, F MINOR, OP. 28 (IRISH)',
#      'conductorName': 'Mahler, Gustav',
#      'soloists': []},
#     {'ID': '50317*1',
#      'composerName': 'Elgar,  Sir  Edward',
#      'workTitle': 'SEA PICTURES, OP. 37',
#      'movement': 'The Sea Slumber Song',
#      'conductorName': 'Mahler, Gustav',
#      'soloists': [{'soloistName': 'Kirkby-Lunn, Louise',
#        'soloistInstrument': 'Contralto',
#        'soloistRoles': 'S'}]},
#     {'ID': '50317*2',
#      'composerName': 'Elgar,  Sir  Edward',
#      'workTitle': 'SEA PICTURES, OP. 37',
#      'movement': 'In Haven (Capri)',
#      'conductorName': 'Mahler, Gustav',
#      'soloists': [{'soloistName': 'Kirkby-Lunn, Louise',
#        'soloistInstrument': 'Contralto',
#        'soloistRoles': 'S'}]},
#     {'ID': '50317*3',
#      'composerName': 'Elgar,  Sir  Edward',
#      'workTitle': 'SEA PICTURES, OP. 37',
#      'movement': 'Sabbath Morning at Sea',
#      'conductorName': 'Mahler, Gustav',
#      'soloists': [{'soloistName': 'Kirkby-Lunn, Louise',
#        'soloistInstrument': 'Contralto',
#        'soloistRoles': 'S'}]},
#     {'ID': '50317*4',
#      'composerName': 'Elgar,  Sir  Edward',
#      'workTitle': 'SEA PICTURES, OP. 37',
#      'movement': 'Where Corals Lie',
#      'conductorName': 'Mahler, Gustav',
#      'soloists': [{'soloistName': 'Kirkby-Lunn, Louise',
#        'soloistInstrument': 'Contralto',
#        'soloistRoles': 'S'}]},
#     {'ID': '0*', 'interval': 'Intermission', 'soloists': []},
#     {'ID': '6323*',
#      'composerName': 'Loeffler,  Charles  Martin',
#      'workTitle': 'LA VILLANELLE DU DIABLE, OP. 9',
#      'conductorName': 'Mahler, Gustav',
#      'soloists': [{'soloistName': 'Sealy, Frank L.',
#        'soloistInstrument': 'Organ',
#        'soloistRoles': 'A'}]},
#     {'ID': '6232*',
#      'composerName': 'MacDowell,  Edward  A.',
#      'workTitle': 'ROLAND SYMPHONY, TWO FRAGMENTS, OP. 30',
#      'conductorName': 'Mahler, Gustav',
#      'soloists': []},
#     {'ID': '2891*',
#      'composerName': 'Hadley,  Henry  Kimball',
#      'workTitle': 'CULPRIT FAY RHAPSODY, OP. 62',
#      'conductorName': 'Mahler, Gustav',
#      'soloists': []}]},
#   ...]}

# %%
# vemos los datos por programa
nycphilraw = pd.json_normalize(datos_raw['programs'])
nycphilraw.head()
# Out:
#                                          id programID  \
# 0  00646b9f-fec7-4ffb-9fb1-faae410bd9dc-0.1      3853
# 1  1118e84e-eb59-46cc-9119-d903375e65e6-0.1      5178
# 2  08536612-27c3-437e-9b44-def21034b06c-0.1     10785
# 3  81a3b8de-1737-4c9e-9318-b839f7c7c4c0-0.1      5887
# 4  09581bb7-8855-4965-b302-fc54cc669041-0.1       305
#
#                                   orchestra   season  \
# 0                     New York Philharmonic  1842-43
# 1                     New York Philharmonic  1842-43
# 2  Musicians from the New York Philharmonic  1842-43
# 3                     New York Philharmonic  1842-43
# 4                     New York Philharmonic  1843-44
#
#                                             concerts  \
# 0  [{'eventType': 'Subscription Season', 'Locatio...
# 1  [{'eventType': 'Subscription Season', 'Locatio...
# 2  [{'eventType': 'Special', 'Location': 'Manhatt...
# 3  [{'eventType': 'Subscription Season', 'Locatio...
# 4  [{'eventType': 'Subscription Season', 'Locatio...
#
#                                                works
# 0  [{'ID': '52446*', 'composerName': 'Beethoven, ...
# 1  [{'ID': '52437*', 'composerName': 'Beethoven, ...
# 2  [{'ID': '52364*1', 'composerName': 'Beethoven,...
# 3  [{'ID': '52434*', 'composerName': 'Beethoven, ...
# 4  [{'ID': '52453*', 'composerName': 'Beethoven, ...

# %%
nycphilraw['concerts'][0]
# Out:
# [{'eventType': 'Subscription Season',
#   'Location': 'Manhattan, NY',
#   'Venue': 'Apollo Rooms',
#   'Date': '1842-12-07T05:00:00Z',
#   'Time': '8:00PM'}]

# %%
# aplanamos el DataFrame por compositor y luego filtramos los de Richard Wagner
nycphil_concerts = pd.json_normalize(datos_raw["programs"], "concerts", ["programID", "season"])
nycphil_concerts.head()
# Out:
#              eventType       Location         Venue                  Date  \
# 0  Subscription Season  Manhattan, NY  Apollo Rooms  1842-12-07T05:00:00Z
# 1  Subscription Season  Manhattan, NY  Apollo Rooms  1843-02-18T05:00:00Z
# 2              Special  Manhattan, NY  Apollo Rooms  1843-04-07T05:00:00Z
# 3  Subscription Season  Manhattan, NY  Apollo Rooms  1843-04-22T05:00:00Z
# 4  Subscription Season  Manhattan, NY  Apollo Rooms  1843-11-18T05:00:00Z
#
#      Time programID   season
# 0  8:00PM      3853  1842-43
# 1  8:00PM      5178  1842-43
# 2  8:00PM     10785  1842-43
# 3  8:00PM      5887  1842-43
# 4    None       305  1843-44

# %%
nycphil_works = pd.json_normalize(datos_raw["programs"], "works", ["programID"])
nycphil_works = nycphil_works[['ID', 'composerName', 'workTitle', 'conductorName', 'movement', 'interval', 'programID']]
nycphil_works.head()
# Out:
#        ID             composerName                         workTitle  \
# 0  52446*  Beethoven,  Ludwig  van  SYMPHONY NO. 5 IN C MINOR, OP.67
# 1  8834*4  Weber,  Carl  Maria Von                            OBERON
# 2   3642*          Hummel,  Johann   QUINTET, PIANO, D MINOR, OP. 74
# 3      0*                      NaN                               NaN
# 4  8834*3  Weber,  Carl  Maria Von                            OBERON
#
#          conductorName                                           movement  \
# 0  Hill, Ureli Corelli                                                NaN
# 1       Timm, Henry C.  "Ozean, du Ungeheuer" (Ocean, thou mighty mons...
# 2                  NaN                                                NaN
# 3                  NaN                                                NaN
# 4    Etienne, Denis G.                                           Overture
#
#        interval programID
# 0           NaN      3853
# 1           NaN      3853
# 2           NaN      3853
# 3  Intermission      3853
# 4           NaN      3853

# %%
nyphil_df = pd.merge(nycphil_works, nycphil_concerts, on='programID')
nyphil_df.head()
# Out:
#        ID             composerName                         workTitle  \
# 0  52446*  Beethoven,  Ludwig  van  SYMPHONY NO. 5 IN C MINOR, OP.67
# 1  8834*4  Weber,  Carl  Maria Von                            OBERON
# 2   3642*          Hummel,  Johann   QUINTET, PIANO, D MINOR, OP. 74
# 3      0*                      NaN                               NaN
# 4  8834*3  Weber,  Carl  Maria Von                            OBERON
#
#          conductorName                                           movement  \
# 0  Hill, Ureli Corelli                                                NaN
# 1       Timm, Henry C.  "Ozean, du Ungeheuer" (Ocean, thou mighty mons...
# 2                  NaN                                                NaN
# 3                  NaN                                                NaN
# 4    Etienne, Denis G.                                           Overture
#
#        interval programID            eventType       Location         Venue  \
# 0           NaN      3853  Subscription Season  Manhattan, NY  Apollo Rooms
# 1           NaN      3853  Subscription Season  Manhattan, NY  Apollo Rooms
# 2           NaN      3853  Subscription Season  Manhattan, NY  Apollo Rooms
# 3  Intermission      3853  Subscription Season  Manhattan, NY  Apollo Rooms
# 4           NaN      3853  Subscription Season  Manhattan, NY  Apollo Rooms
#
#                    Date    Time   season
# 0  1842-12-07T05:00:00Z  8:00PM  1842-43
# 1  1842-12-07T05:00:00Z  8:00PM  1842-43
# 2  1842-12-07T05:00:00Z  8:00PM  1842-43
# 3  1842-12-07T05:00:00Z  8:00PM  1842-43
# 4  1842-12-07T05:00:00Z  8:00PM  1842-43

# %% [markdown]
# #### (*2 pt*) 1.2.2 Muestre 7 filas de datos al azar de su DataFrame
#
# Respuesta:

# %%
# pregunta 1.2.2
nyphil_df.sample(7)
# Out:
#              ID                composerName  \
# 8942     50620*            Wagner,  Richard
# 126622   51642*  Mozart,  Wolfgang  Amadeus
# 38851    53052*            Lyadov,  Anatoli
# 76765    13240*         Gabrieli,  Giovanni
# 67915     6468*           Schuman,  William
# 124737       0*                         NaN
# 8618    50317*2         Elgar,  Sir  Edward
#
#                                          workTitle        conductorName  \
# 8942                      SIEGFRIED IDYLL, WWV 103      Stransky, Josef
# 126622  SYMPHONY NO. 35, D MAJOR, K.385, "HAFFNER"         Glover, Jane
# 38851            RUSSIAN FOLK SONGS, EIGHT, OP. 58  Smallens, Alexander
# 76765     CANZON PER SONAR DUODECIMI TONI, CH. 174        Ceccato, Aldo
# 67915                         PHILHARMONIC FANFARE   Steinberg, William
# 124737                                         NaN                  NaN
# 8618                          SEA PICTURES, OP. 37       Mahler, Gustav
#
#                 movement      interval programID            eventType  \
# 8942                 NaN           NaN      3717                 Tour
# 126622               NaN           NaN     14831  Subscription Season
# 38851                NaN           NaN     11847      Stadium Concert
# 76765                NaN           NaN       206  Subscription Season
# 67915                NaN           NaN      1159                Parks
# 124737               NaN  Intermission     14619                Parks
# 8618    In Haven (Capri)           NaN      5648  Subscription Season
#
#                Location                         Venue                  Date  \
# 8942    Springfield, MA          Court Square Theater  1911-11-08T05:00:00Z
# 126622    Manhattan, NY             David Geffen Hall  2024-05-08T04:00:00Z
# 38851     Manhattan, NY              Lewisohn Stadium  1939-07-28T04:00:00Z
# 76765     Manhattan, NY             Avery Fisher Hall  1974-04-12T04:00:00Z
# 67915         Bronx, NY           NY Botanical Garden  1965-08-14T04:00:00Z
# 124737    Manhattan, NY  The Great Lawn, Central Park  2022-06-15T04:00:00Z
# 8618      Manhattan, NY                 Carnegie Hall  1911-02-17T05:00:00Z
#
#           Time   season
# 8942    8:15PM  1911-12
# 126622  7:30PM  2023-24
# 38851   8:30PM  1938-39
# 76765   2:00PM  1973-74
# 67915   5:30PM  1964-65
# 124737  8:00PM  2021-22
# 8618    2:30PM  1910-11

# %% [markdown]
# #### (*2 pts*) 1.2.3 Imprima una lista de los tipos de datos que tiene en cada columna.
#
# Respuesta:

# %%
# pregunta 1.2.3
nyphil_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 126756 entries, 0 to 126755
# Data columns (total 13 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   ID             126756 non-null  object
#  1   composerName   108085 non-null  object
#  2   workTitle      108073 non-null  object
#  3   conductorName  100288 non-null  object
#  4   movement       35253 non-null   object
#  5   interval       18670 non-null   object
#  6   programID      126756 non-null  object
#  7   eventType      126756 non-null  object
#  8   Location       126756 non-null  object
#  9   Venue          126756 non-null  object
#  10  Date           126756 non-null  object
#  11  Time           126756 non-null  object
#  12  season         126756 non-null  object
# dtypes: object(13)
# memory usage: 12.6+ MB

# %% [markdown]
# #### (*2 pts*) 1.2.4 Conteste:
#
# Su base ahora cuenta con un listado de los compositores interpretados en cada concierto que ha hecho la filarmónica. ¿Cuál es el total de combinaciones concierto/compositor que tiene su base?
#
# Respuesta:

# %%
# pregunta 1.2.4
len(nyphil_df)
# Out:
# 126756

# %% [markdown]
# ### 1.3 Revisión y limpieza de datos
#
# Usando el DataFrame de pandas de la pregunta anterior realice las siguientes actividades. Puede agregar celdas si lo necesita.

# %% [markdown]
# #### (*5 pts*) 1.3.1 Conteste: ¿Estan correctos todos los tipos de datos que asumió Pandas? Si no lo están, justifique por qué y transforme la columna al tipo correcto.
#
# Respuesta:

# %% [markdown]
# En este caso vemos que la mayoría de las columnas poseen tipos de datos razonables para la información que existe ahí.
#
# La excepción son `programID`, `eventType` y `Date` que están como object.
# - `programID` podría estar en `int` dado que todos son números.
# - `eventType` tiene un conjunto limitado de opciones, así que podría estar como categoría.
# - `Date` debe estar como fecha.

# %%
nyphil_df['programID'] = nyphil_df['programID'].astype('int')

# %%
nyphil_df['eventType'] = nyphil_df['eventType'].astype('category')
nyphil_df['eventType'].unique()
# Out:
# ['Subscription Season', 'Special', 'Chamber', 'Festival', 'Non-Subscription', ..., 'Community', 'NY Phil @ Noon', 'Artist Spotlight', 'Take a Breath', 'Pride Alliance']
# Length: 71
# Categories (71, object): ['Artist Spotlight', 'Artist in Residence / Soloist Recital', 'Artist in Residence recital', 'Bandwagon', ..., 'World Trade Center - Chamber', 'World's Fair', 'Young People's Concert', 'Young People's Concerts for Schools']

# %%
nyphil_df['Date'] = pd.to_datetime(nyphil_df['Date'])

# %%
nyphil_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 126756 entries, 0 to 126755
# Data columns (total 13 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   ID             126756 non-null  object
#  1   composerName   108085 non-null  object
#  2   workTitle      108073 non-null  object
#  3   conductorName  100288 non-null  object
#  4   movement       35253 non-null   object
#  5   interval       18670 non-null   object
#  6   programID      126756 non-null  int32
#  7   eventType      126756 non-null  category
#  8   Location       126756 non-null  object
#  9   Venue          126756 non-null  object
#  10  Date           126756 non-null  datetime64[ns, UTC]
#  11  Time           126756 non-null  object
#  12  season         126756 non-null  object
# dtypes: category(1), datetime64[ns, UTC](1), int32(1), object(10)
# memory usage: 11.2+ MB

# %% [markdown]
# #### (*3 pts*) 1.3.2 Conteste: ¿Hay columnas que usted eliminaría del DataFrame? Si hay alguna, indique por qué, y si no hay ninguna, también justifique por qué.
#
# Respuesta:

# %% [markdown]
# En este caso las columnas `movement` e `interval` tienen muy pocos datos no nulos, por lo que se podrían eliminar según sean los objetivos del estudio posterior.

# %% [markdown]
# #### (*3 pts*) 1.3.3: Escriba un código que elimine las columnas identificadas en el punto anterior. Si usted no identificó columnas a eliminar, escriba en una celda de texto cómo sería el comando para eliminar una columna innecesaria en su DataFrame.
#
# Respuesta:

# %%
# pregunta 1.3.3
nyphil_df.drop(columns=['movement', 'interval'], inplace=True)
nyphil_df.head(5)
# Out:
#        ID             composerName                         workTitle  \
# 0  52446*  Beethoven,  Ludwig  van  SYMPHONY NO. 5 IN C MINOR, OP.67
# 1  8834*4  Weber,  Carl  Maria Von                            OBERON
# 2   3642*          Hummel,  Johann   QUINTET, PIANO, D MINOR, OP. 74
# 3      0*                      NaN                               NaN
# 4  8834*3  Weber,  Carl  Maria Von                            OBERON
#
#          conductorName  programID            eventType       Location  \
# 0  Hill, Ureli Corelli       3853  Subscription Season  Manhattan, NY
# 1       Timm, Henry C.       3853  Subscription Season  Manhattan, NY
# 2                  NaN       3853  Subscription Season  Manhattan, NY
# 3                  NaN       3853  Subscription Season  Manhattan, NY
# 4    Etienne, Denis G.       3853  Subscription Season  Manhattan, NY
#
#           Venue                      Date    Time   season
# 0  Apollo Rooms 1842-12-07 05:00:00+00:00  8:00PM  1842-43
# 1  Apollo Rooms 1842-12-07 05:00:00+00:00  8:00PM  1842-43
# 2  Apollo Rooms 1842-12-07 05:00:00+00:00  8:00PM  1842-43
# 3  Apollo Rooms 1842-12-07 05:00:00+00:00  8:00PM  1842-43
# 4  Apollo Rooms 1842-12-07 05:00:00+00:00  8:00PM  1842-43

# %% [markdown]
# #### (*5 pts*) 1.3.4: Conteste: ¿Hay datos duplicados en su DataFrame? Escriba un código que los detecte y muestre los registros duplicados si es que los hay.
#
# Respuesta:

# %%
# pregunta 1.3.4
duplicados = nyphil_df.duplicated(keep=False)
datos_duplicados = nyphil_df[duplicados]
datos_duplicados
# Out:
#             ID               composerName  \
# 67      52512*        Mendelssohn,  Felix
# 71      52512*        Mendelssohn,  Felix
# 819         0*                        NaN
# 823         0*                        NaN
# 879         0*                        NaN
# ...        ...                        ...
# 115967  2331*7  Rimsky-Korsakov,  Nikolai
# 121556  8742*1         Sondheim,  Stephen
# 121559  8742*1         Sondheim,  Stephen
# 124985   6979*           Debussy,  Claude
# 124996   6979*           Debussy,  Claude
#
#                                        workTitle    conductorName  programID  \
# 67      HEBRIDES (FINGAL'S CAVE) OVERTURE, OP.26    Loder, George       6310
# 71      HEBRIDES (FINGAL'S CAVE) OVERTURE, OP.26    Loder, George       6310
# 819                                          NaN              NaN       4537
# 823                                          NaN              NaN       4537
# 879                                          NaN              NaN       6144
# ...                                          ...              ...        ...
# 115967                      SCHEHERAZADE, OP. 35  Scaglione, Case      11943
# 121556                     COMPANY (ARR. Tunick)    Einhorn, Andy      14112
# 121559                     COMPANY (ARR. Tunick)    Einhorn, Andy      14112
# 124985                                    SYRINX              NaN      14783
# 124996                                    SYRINX              NaN      14783
#
#                                   eventType       Location  \
# 67                      Subscription Season  Manhattan, NY
# 71                      Subscription Season  Manhattan, NY
# 819                     Subscription Season  Manhattan, NY
# 823                     Subscription Season  Manhattan, NY
# 879                     Subscription Season  Manhattan, NY
# ...                                     ...            ...
# 115967  Young People's Concerts for Schools  Manhattan, NY
# 121556         Pension Fund Benefit Concert  Manhattan, NY
# 121559         Pension Fund Benefit Concert  Manhattan, NY
# 124985                              Chamber  Manhattan, NY
# 124996                              Chamber  Manhattan, NY
#
#                                                   Venue  \
# 67                                         Apollo Rooms
# 71                                         Apollo Rooms
# 819                                    Academy of Music
# 823                                    Academy of Music
# 879                                    Academy of Music
# ...                                                 ...
# 115967                                Avery Fisher Hall
# 121556                                David Geffen Hall
# 121559                                David Geffen Hall
# 124985  Theresa L. Kaufmann Concert Hall, 92nd St. YMHA
# 124996  Theresa L. Kaufmann Concert Hall, 92nd St. YMHA
#
#                             Date     Time   season
# 67     1844-11-16 05:00:00+00:00   8:00PM  1844-45
# 71     1844-11-16 05:00:00+00:00   8:00PM  1844-45
# 819    1864-11-05 05:00:00+00:00   8:00PM  1864-65
# 823    1864-11-05 05:00:00+00:00   8:00PM  1864-65
# 879    1866-01-27 05:00:00+00:00   8:00PM  1865-66
# ...                          ...      ...      ...
# 115967 2013-05-23 04:00:00+00:00  10:30AM  2012-13
# 121556 2018-05-01 04:00:00+00:00   7:30PM  2017-18
# 121559 2018-05-01 04:00:00+00:00   7:30PM  2017-18
# 124985 2022-11-20 05:00:00+00:00   3:00PM  2022-23
# 124996 2022-11-20 05:00:00+00:00   3:00PM  2022-23
#
# [887 rows x 11 columns]

# %% [markdown]
# #### (*3 pts*) 1.3.5: Escriba un código que elimine las filas duplicadas, si es que las hubiera, dejando el perimer registro del DataFrame si hay duplicados.
#
# Respuesta:

# %%
# pregunta 1.3.5
nyphil_df_limpio = nyphil_df.drop_duplicates(keep='first')
nyphil_df_limpio
# Out:
#               ID                composerName  \
# 0         52446*     Beethoven,  Ludwig  van
# 1         8834*4     Weber,  Carl  Maria Von
# 2          3642*             Hummel,  Johann
# 3             0*                         NaN
# 4         8834*3     Weber,  Carl  Maria Von
# ...          ...                         ...
# 126751    1807*6          Prokofiev,  Sergei
# 126752    51664*  Mozart,  Wolfgang  Amadeus
# 126753        0*                         NaN
# 126754    52390*             Copland,  Aaron
# 126755  50296*10         Elgar,  Sir  Edward
#
#                                             workTitle        conductorName  \
# 0                    SYMPHONY NO. 5 IN C MINOR, OP.67  Hill, Ureli Corelli
# 1                                              OBERON       Timm, Henry C.
# 2                     QUINTET, PIANO, D MINOR, OP. 74                  NaN
# 3                                                 NaN                  NaN
# 4                                              OBERON    Etienne, Denis G.
# ...                                               ...                  ...
# 126751  QUINTET FOR OB/CL/VLN/VLA/CB, OP. 39, G MINOR                  NaN
# 126752                SYMPHONY NO. 40, G MINOR, K.550     van Zweden, Jaap
# 126753                                            NaN                  NaN
# 126754                                 SYMPHONY NO. 3     van Zweden, Jaap
# 126755                      ENIGMA VARIATIONS, OP. 36     van Zweden, Jaap
#
#         programID                    eventType           Location  \
# 0            3853          Subscription Season      Manhattan, NY
# 1            3853          Subscription Season      Manhattan, NY
# 2            3853          Subscription Season      Manhattan, NY
# 3            3853          Subscription Season      Manhattan, NY
# 4            3853          Subscription Season      Manhattan, NY
# ...           ...                          ...                ...
# 126751      15035  Parks - Free Indoor Concert  Staten Island, NY
# 126752      15005                         Tour   Guangzhou, CHINA
# 126753      15005                         Tour   Guangzhou, CHINA
# 126754      15005                         Tour   Guangzhou, CHINA
# 126755      15005                         Tour   Guangzhou, CHINA
#
#                         Venue                      Date    Time   season
# 0                Apollo Rooms 1842-12-07 05:00:00+00:00  8:00PM  1842-43
# 1                Apollo Rooms 1842-12-07 05:00:00+00:00  8:00PM  1842-43
# 2                Apollo Rooms 1842-12-07 05:00:00+00:00  8:00PM  1842-43
# 3                Apollo Rooms 1842-12-07 05:00:00+00:00  8:00PM  1842-43
# 4                Apollo Rooms 1842-12-07 05:00:00+00:00  8:00PM  1842-43
# ...                       ...                       ...     ...      ...
# 126751     St. George Theatre 2024-06-16 04:00:00+00:00  4:00PM  2023-24
# 126752  Guangzhou Opera House 2024-06-27 04:00:00+00:00  7:30PM  2023-24
# 126753  Guangzhou Opera House 2024-06-27 04:00:00+00:00  7:30PM  2023-24
# 126754  Guangzhou Opera House 2024-06-27 04:00:00+00:00  7:30PM  2023-24
# 126755  Guangzhou Opera House 2024-06-27 04:00:00+00:00  7:30PM  2023-24
#
# [126218 rows x 11 columns]

# %% [markdown]
# #### (*5 pts*) 1.3.6: La columna `eventType	` tiene todas las condiciones para ser una columna de datos categóricos. Explique por qué podrían ser datos categóricos y transforme esa columna en variables categóricas.
#
# Respuesta:

# %% [markdown]
# Esta columna tiene datos cuyos valores están limitados a pocos posibles valores. Esto es justo lo que se necesita para el caso de variables categóricas.

# %%
# pregunta 1.3.6
nyphil_df_limpio['eventType'] = nyphil_df_limpio['eventType'].astype('category')
# Out:
# C:\Users\rodri\AppData\Local\Temp\ipykernel_20328\2034492340.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   nyphil_df_limpio['eventType'] = nyphil_df_limpio['eventType'].astype('category')

# %%
nyphil_df_limpio.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 126218 entries, 0 to 126755
# Data columns (total 11 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   ID             126218 non-null  object
#  1   composerName   107658 non-null  object
#  2   workTitle      107646 non-null  object
#  3   conductorName  99874 non-null   object
#  4   programID      126218 non-null  int32
#  5   eventType      126218 non-null  category
#  6   Location       126218 non-null  object
#  7   Venue          126218 non-null  object
#  8   Date           126218 non-null  datetime64[ns, UTC]
#  9   Time           126218 non-null  object
#  10  season         126218 non-null  object
# dtypes: category(1), datetime64[ns, UTC](1), int32(1), object(8)
# memory usage: 10.2+ MB

# %% [markdown]
# ### 1.4 Análisis de datos
#
# En la pregunta anterior hicimos algunos elementos básicos de limpieza. Usando el DataFrame limpio resultante final de la pregunta 1.3, conteste las siguientes preguntas. Puede agregar celdas si lo necesita.

# %% [markdown]
# #### (*7 pts*) 1.4.1 ¿Cuáles son los 20 compositores más tocados por la filarmónica? Imprima el nombre de los compositores.
#
# Respuesta:

# %%
composers = nyphil_df_limpio['composerName'].value_counts()
composers.head(20)
# Out:
# composerName
# Beethoven,  Ludwig  van        6698
# Wagner,  Richard               6291
# Tchaikovsky,  Pyotr  Ilyich    5011
# Mozart,  Wolfgang  Amadeus     4522
# Brahms,  Johannes              3812
# Strauss,  Richard              2520
# Bach,  Johann  Sebastian       2217
# Prokofiev,  Sergei             2111
# Berlioz,  Hector               2102
# Mendelssohn,  Felix            2076
# Handel,  George  Frideric      2044
# Dvorak,  Antonín               1899
# Stravinsky,  Igor              1840
# Ravel,  Maurice                1778
# Schubert,  Franz               1750
# Debussy,  Claude               1717
# Schumann,  Robert              1462
# Gershwin,  George              1458
# Haydn,  Franz  Joseph          1435
# Liszt,  Franz                  1320
# Name: count, dtype: int64

# %% [markdown]
# #### (*5 pts*) 1.4.2 ¿Cuáles son los 15 lugares más comunes donde ha tocado la Filarmónica? ¿Hacen sentido estos resultados? Explique por qué.
#
# Respuesta:

# %%
locations = nyphil_df_limpio['Location'].value_counts()
locations.head(15)
# Out:
# Location
# Manhattan, NY        106138
# Brooklyn, NY           1973
# Philadelphia, PA       1348
# Vail, CO                862
# Bronx, NY               594
# Queens, NY              560
# Washington, DC          528
# Staten Island, NY       402
# Greenvale, NY           389
# Baltimore, MD           350
# Tokyo, JAPAN            303
# London, ENGLAND         254
# Newark, NJ              240
# Holmdel, NJ             214
# Princeton, NJ           203
# Name: count, dtype: int64

# %% [markdown]
# #### (*7 pts*) 1.4.3 ¿Cuáles son los tipos de evento más comunes? (el tipo de evento está en la columna `eventType`).
#
# Respuesta:

# %%
eventType = nyphil_df_limpio['eventType'].value_counts()
eventType.head(15)
# Out:
# eventType
# Subscription Season                    66415
# Stadium Concert                        13397
# Tour                                   13028
# Young People's Concert                  5967
# Promenade                               3473
# Parks                                   2637
# Special                                 2479
# Chamber                                 2421
# Student Concert                         2148
# Runout                                  1600
# Festival                                1306
# Non-Subscription                        1247
# Pension Fund Benefit Concert            1146
# Young People's Concerts for Schools      834
# Summertime Classics                      811
# Name: count, dtype: int64

# %% [markdown]
# #### (*5 pts*) 1.4.4 Usando los datos anteriores, arme un nuevo DataFrame que contenga sólo conciertos hechos en el lugar con más conciertos, con el tipo de evento más común, y con el compositor más tocado por la filarmónica.
#
# Respuesta:

# %%
nyphil_selec = nyphil_df_limpio[(nyphil_df_limpio['composerName']==composers.keys()[0]) & (nyphil_df_limpio['Location']==locations.keys()[0]) & (nyphil_df_limpio['eventType']==eventType.keys()[0])]
nyphil_selec
# Out:
#             ID             composerName  \
# 0       52446*  Beethoven,  Ludwig  van
# 6       8837*6  Beethoven,  Ludwig  van
# 9       52437*  Beethoven,  Ludwig  van
# 30      52434*  Beethoven,  Ludwig  van
# 34      52425*  Beethoven,  Ludwig  van
# ...        ...                      ...
# 126456  52446*  Beethoven,  Ludwig  van
# 126473  52446*  Beethoven,  Ludwig  van
# 126625   1855*  Beethoven,  Ludwig  van
# 126626   1855*  Beethoven,  Ludwig  van
# 126627   1855*  Beethoven,  Ludwig  van
#
#                                               workTitle        conductorName  \
# 0                      SYMPHONY NO. 5 IN C MINOR, OP.67  Hill, Ureli Corelli
# 6                                       FIDELIO, OP. 72       Timm, Henry C.
# 9       SYMPHONY NO. 3 IN E FLAT MAJOR, OP. 55 (EROICA)  Hill, Ureli Corelli
# 30                     SYMPHONY NO. 2 IN D MAJOR, OP.36      Boucher, Alfred
# 34                          SEPTET, E-FLAT MAJOR, OP.20                  NaN
# ...                                                 ...                  ...
# 126456                 SYMPHONY NO. 5 IN C MINOR, OP.67     van Zweden, Jaap
# 126473                 SYMPHONY NO. 5 IN C MINOR, OP.67     van Zweden, Jaap
# 126625                              AH!  PERFIDO, OP.65         Glover, Jane
# 126626                              AH!  PERFIDO, OP.65         Glover, Jane
# 126627                              AH!  PERFIDO, OP.65         Glover, Jane
#
#         programID            eventType       Location              Venue  \
# 0            3853  Subscription Season  Manhattan, NY       Apollo Rooms
# 6            3853  Subscription Season  Manhattan, NY       Apollo Rooms
# 9            5178  Subscription Season  Manhattan, NY       Apollo Rooms
# 30           5887  Subscription Season  Manhattan, NY       Apollo Rooms
# 34           5887  Subscription Season  Manhattan, NY       Apollo Rooms
# ...           ...                  ...            ...                ...
# 126456      14820  Subscription Season  Manhattan, NY  David Geffen Hall
# 126473      15001  Subscription Season  Manhattan, NY  David Geffen Hall
# 126625      14831  Subscription Season  Manhattan, NY  David Geffen Hall
# 126626      14831  Subscription Season  Manhattan, NY  David Geffen Hall
# 126627      14831  Subscription Season  Manhattan, NY  David Geffen Hall
#
#                             Date    Time   season
# 0      1842-12-07 05:00:00+00:00  8:00PM  1842-43
# 6      1842-12-07 05:00:00+00:00  8:00PM  1842-43
# 9      1843-02-18 05:00:00+00:00  8:00PM  1842-43
# 30     1843-04-22 05:00:00+00:00  8:00PM  1842-43
# 34     1843-04-22 05:00:00+00:00  8:00PM  1842-43
# ...                          ...     ...      ...
# 126456 2024-03-16 04:00:00+00:00  8:00PM  2023-24
# 126473 2024-03-19 04:00:00+00:00  7:30PM  2023-24
# 126625 2024-05-08 04:00:00+00:00  7:30PM  2023-24
# 126626 2024-05-09 04:00:00+00:00  7:30PM  2023-24
# 126627 2024-05-10 04:00:00+00:00  2:00PM  2023-24
#
# [4081 rows x 11 columns]

# %% [markdown]
# #### (*3 pts*) 1.4.5 Considerando su nuevo DataFrame, ¿cuál es el conductor qué más ha dirigido la Filarmónica en este subconjunto?
#
# Respuesta:

# %%
conductors = nyphil_selec['conductorName'].value_counts()
conductors.head(15)
# Out:
# conductorName
# Damrosch, Walter        440
# Stransky, Josef         207
# Bernstein, Leonard      192
# Masur, Kurt             185
# Walter, Bruno           171
# Szell, George           170
# Toscanini, Arturo       158
# Mitropoulos, Dimitri    154
# Mehta, Zubin            133
# Barbirolli , John       118
# Mengelberg, Willem      110
# Maazel, Lorin           105
# Rodzinski, Artur         82
# Leinsdorf, Erich         81
# Bergmann, Carl           75
# Name: count, dtype: int64

# %% [markdown]
# #### (*6 pts*) 1.4.6 Considerando su nuevo DataFrame ¿hay algún cambio en el número de obras tocadas por este compositor más importante a lo largo del tiempo?
#
# Para contestar esta pregunta realice un gráfico que muestre la cantidad de interpretaciones de este compositor para cada temporada. No olvide poner título al gráfico y a los ejes, y comentar lo que infiere usted al ver el gráfico.
#
# Respuesta:

# %%
cantidad = nyphil_selec['season'].value_counts()
cantidad.head(15)
# Out:
# season
# 1923-24    107
# 1953-54     70
# 1920-21     68
# 1959-60     59
# 1948-49     59
# 1907-08     58
# 1933-34     56
# 1921-22     52
# 1926-27     52
# 1931-32     50
# 1962-63     49
# 1998-99     47
# 1925-26     46
# 1947-48     45
# 1913-14     45
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt

fig = plt.figure(figsize=(8,8))
ax = fig.add_subplot(111)

ax.plot(sorted(cantidad.keys()), cantidad[sorted(cantidad.keys())],'.')
ax.set_xlabel('Temporada')
ax.set_ylabel('Conciertos')
ax.set_title('Conciertos por temporada')
# Out:
# Text(0.5, 1.0, 'Conciertos por temporada')
